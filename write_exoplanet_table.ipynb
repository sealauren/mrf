# %%
#%matplotlib osx
# %pylab inline
import numpy as np
import math
#import astroypy
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("all_exos_errors7.csv",skiprows=[1])
df.sort(inplace=True)
df.head()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 43 columns):
# NAME            5  non-null values
# MASS            5  non-null values
# MASSUPPER       5  non-null values
# MASSLOWER       5  non-null values
# UMASS           5  non-null values
# R               5  non-null values
# RUPPER          5  non-null values
# RLOWER          5  non-null values
# UR              5  non-null values
# DENSITY         5  non-null values
# DENSITYUPPER    5  non-null values
# DENSITYLOWER    5  non-null values
# UDENSITY        5  non-null values
# A               5  non-null values
# AUPPER          5  non-null values
# ALOWER          5  non-null values
# UA              5  non-null values
# PER             5  non-null values
# ECC             5  non-null values
# MSTAR           5  non-null values
# MSTARUPPER      5  non-null values
# MSTARLOWER      5  non-null values
# UMSTAR          5  non-null values
# RSTAR           5  non-null values
# RSTARUPPER      5  non-null values
# RSTARLOWER      5  non-null values
# URSTAR          5  non-null values
# RHOSTAR         3  non-null values
# TEFF            5  non-null values
# TEFFUPPER       5  non-null values
# TEFFLOWER       5  non-null values
# UTEFF           5  non-null values
# LOGG            5  non-null values
# FE              5  non-null values
# FEUPPER         5  non-null values
# FELOWER         5  non-null values
# UFE             5  non-null values
# VSINI           5  non-null values
# SHK             1  non-null values
# ORBREF          5  non-null values
# ORBURL          5  non-null values
# FIRSTREF        5  non-null values
# FIRSTURL        5  non-null values
# dtypes: float64(38), object(5)

# %%
new_columns = [c.lower() for c in df.columns]
df.columns = new_columns
print df.columns
# Out:
# Index([u'name', u'mass', u'massupper', u'masslower', u'umass', u'r', u'rupper', u'rlower', u'ur', u'density', u'densityupper', u'densitylower', u'udensity', u'a', u'aupper', u'alower', u'ua', u'per', u'ecc', u'mstar', u'mstarupper', u'mstarlower', u'umstar', u'rstar', u'rstarupper', u'rstarlower', u'urstar', u'rhostar', u'teff', u'teffupper', u'tefflower', u'uteff', u'logg', u'fe', u'feupper', u'felower', u'ufe', u'vsini', u'shk', u'orbref', u'orburl', u'firstref', u'firsturl'], dtype=object)

# %%
df['m'] = df.mass
df['um'] = df.umass
df['rho'] = df.density
df['urho'] = df.udensity
df.columns
# Out:
# Index([u'name', u'mass', u'massupper', u'masslower', u'umass', u'r', u'rupper', u'rlower', u'ur', u'density', u'densityupper', u'densitylower', u'udensity', u'a', u'aupper', u'alower', u'ua', u'per', u'ecc', u'mstar', u'mstarupper', u'mstarlower', u'umstar', u'rstar', u'rstarupper', u'rstarlower', u'urstar', u'rhostar', u'teff', u'teffupper', u'tefflower', u'uteff', u'logg', u'fe', u'feupper', u'felower', u'ufe', u'vsini', u'shk', u'orbref', u'orburl', u'firstref', u'firsturl', u'm', u'um', u'rho', u'urho'], dtype=object)

# %%
# Need to build local lookup table, or use wolfram_lookup, to get common values
#%load 'astrophysical_constants.txt'

# %%
mearth = 5.9721986E27 #grams
rearth = 6.3675E8 #centimeters
msun = 1.988435E33 #grams
rsun = 6.955E10 #centimeters
cmperau=1.496E13
lsun = 3.846E33 #ergs per second
tsun = 5780 #kelvins

# %%
#df['rho']= df.m*mearth/(4/3*np.pi*(df.r*rearth)**3) # cgs
#df['urho'] = np.sqrt((df.umsini/df.m)**2. + (3*df.ur/df.r)**2.)*df.rho

# %% [markdown]
# Load planets from Geoff's paper and merge the planetary and stellar tables.

# %%
df22 = pd.read_csv('h22_orbital_pars_annotated.txt',skiprows=[1],skipinitialspace=True)
df22_stars = pd.read_csv('h22_star_prop.txt',skipinitialspace=True)
df22.columns = [c.strip() for c in df22.columns]
new_columns = [c.lower() for c in df22.columns]
df22.columns = new_columns
df22.columns = ['name','per','r','ur','m','um','rho','urho','k','uk','rhostar','urhostar','b','ub','rprs','tt','mupper']
df22_stars.koi_star = [koi.strip().lstrip('k0') for koi in df22_stars.koi_star]
df22_stars
df22_stars['fe'] = df22_stars.feh
df22_stars['ufe'] = df22_stars.ufeh
df22['koi_star']=[k.strip()[:-3] for k in df22.name]
df22_full = pd.merge(df22,df22_stars)
df22_full['name'] = ["KOI-"+koi for koi in df22_full.name]
df22_full.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 37 columns):
# name        5  non-null values
# per         5  non-null values
# r           5  non-null values
# ur          5  non-null values
# m           5  non-null values
# um          5  non-null values
# rho         5  non-null values
# urho        5  non-null values
# k           5  non-null values
# uk          5  non-null values
# rhostar     5  non-null values
# urhostar    5  non-null values
# b           5  non-null values
# ub          5  non-null values
# rprs        5  non-null values
# tt          5  non-null values
# mupper      5  non-null values
# koi_star    5  non-null values
# kid         5  non-null values
# ra          5  non-null values
# dec         5  non-null values
# teff        5  non-null values
# uteff       5  non-null values
# logg        5  non-null values
# ulogg       5  non-null values
# feh         5  non-null values
# ufeh        5  non-null values
# mstar       5  non-null values
# umstar      5  non-null values
# rstar       5  non-null values
# urstar      5  non-null values
# vsini       5  non-null values
# vmag        5  non-null values
# age         5  non-null values
# source      5  non-null values
# fe          5  non-null values
# ufe         5  non-null values
# dtypes: float64(29), int64(3), object(5)

# %% [markdown]
# Use Kepler's Law to get semi-major axis H22 planets and merge.

# %%
df22_full['a'] = pow(pow(df22_full.per/365.25,2.) * df22_full.mstar , 1/3.)
df22_full['ecc'] = [0.0] * len(df22_full)
df22_full['orbref'] = "Marcy 2013"
df22_full['firstref'] = "Borucki 2011"
df = df.append(df22_full)

# %% [markdown]
# Add Kepler-78 and KOI-94.

# %%
K78data = [{'name':'Kepler-78 b','m': 1.69, 'um': 0.41, 'r':1.20, 'ur':0.09, 'rho':5.3, 'urho':1.8, 
           'per':8.5/24.,'a':3.0*0.74*rsun/cmperau,'ua':.75*0.74*rsun/cmperau,'ecc':0.0,
           'mstar':0.81, 'umstar':0.05, 'rstar':0.74, 'urstar':0.09, 'teff':5089, 'uteff':50,
           'firstref':"Sanchis-Ojeda 2013", 'orbref':"Sanchis-Ojeda (2013)"
           }]
KOI94data = {'name':['KOI-94 b', 'KOI-94 c', 'KOI-94 d', 'KOI-94 e'],
             'm': [10.5, 15.6, 106., 35.], 
             'um': [4.6, 10.6, 11, 23.], 
             'r':[1.71, 4.32, 11.27, 6.56], 
             'ur':[0.16, 0.41, 1.06, 0.62], 
             'rho':[10.1, 0.91, 0.363, 0.60], 
             'urhoupper':[5.5, 0.36, 0.101, 0.26], 
             'urholower':[5.5, 0.91, 0.101, 0.56], 
            'urho':[5.5, 0.64, 0.101, 0.41], 
           'per':[3.743208, 10.423648, 22.3429890, 54.32031],
           'a':[0.05119, 0.1013, 0.1684, 0.3046],
           'ua':[0.00067, 0.0013, 0.0022, 0.0040],
           'ecc':[0.25, 0.43, 0.022, 0.019],
           'mstar':1.277, 'umstar':0.050, 'rstar':1.52, 'urstar':0.14, 
           'teff':6182, 'uteff':58, 'logg':4.181,'ulogg':0.066,
           'fe':0.0228,'ufe':0.0020, 'vsini':7.3, 'age':3.16,
           'firstref':["Borucki 2011","Borucki 2011","Borucki 2011","Batalha 2013"],
           'orbref':"Weiss 2013"
           }
K78df = pd.DataFrame(K78data)
KOI94df = pd.DataFrame(KOI94data)
df = df.append(K78df)
df = df.append(KOI94df)
df = df.set_index('name')

# %%
# update Ms and Rs with literature values
df.loc['55 Cnc e',['r','ur','orbref']] = [1.990, 0.084, "Endl 2012, Dragomir 2013"]
df.loc['CoRoT-7 b',['m','um','r','ur','orbref']] = [ 7.42 , 1.21 ,  1.58 , 0.1 , "Hatzes 2012"]
df.loc['GJ 1214 b',['m','um','r','ur','orbref']] = [ 6.45 , 0.91 ,  2.65 , 0.09 , "Carter 2011"]
df.loc['Kepler-10 b',['m','um','r','ur','rho','urho','mstar','umstar','rstar','urstar',
                      'teff','uteff','fe','ufe','age','orbref']] = [ 4.60, 1.26, 1.46, 0.02, 8.15, 2.26, 0.913, 0.022, 1.065, 0.009 , 
     5643, 75, -0.15, 0.07, 10.41, "Fogtmann-Shulz 2013"]
df.loc[['55 Cnc e', 'CoRoT-7 b', 'GJ 1214 b', 'KOI-94 b','Kepler-10 b'],['m','um','r','ur','mstar','rstar','ufe','orbref']]
# Out:
#                      m        um     r     ur  mstar  rstar    ufe  \
# 55 Cnc e      8.379902  0.392415  1.99  0.084  0.905  0.943  0.030
# CoRoT-7 b     7.420000  1.210000  1.58  0.100  0.930  0.870  0.040
# GJ 1214 b     6.450000  0.910000  2.65  0.090  0.157  0.211    NaN
# KOI-94 b     10.500000  4.600000  1.71  0.160  1.277  1.520  0.002
# Kepler-10 b   4.600000  1.260000  1.46  0.020  0.913  1.065  0.070
#
#                                orbref
# 55 Cnc e     Endl 2012, Dragomir 2013
# CoRoT-7 b                 Hatzes 2012
# GJ 1214 b                 Carter 2011
# KOI-94 b                   Weiss 2013
# Kepler-10 b       Fogtmann-Shulz 2013

# %%
# propagate Ms and Rs to new densities
df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'rho'] = \
df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'m']/(4/3. * pi* (df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'r'])**3.)*mearth/rearth**3.
df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'urho'] = df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'rho'] * \
np.sqrt((3 * df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'ur']/df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'r'])**2. + \
        (df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'um']/df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],'m'])**2.)
df.loc[['55 Cnc e','CoRoT-7 b','GJ 1214 b'],['rho','urho']]
# Out:
#                  rho      urho
# 55 Cnc e    5.872439  0.792862
# CoRoT-7 b  10.388944  2.600240
# GJ 1214 b   1.914083  0.333105

# %%
flux_earth = lsun/(4*np.pi*cmperau**2.) # flux on earth
df['flux']=df.rstar**2*(df.teff/5778.)**4/df.a**2 * np.sqrt(1./(1 - df.ecc**2))  #time avg. flux on the planet in earth fluxes
df['uflux'] = df.flux * np.sqrt((4*df.uteff/df.teff)**2. + (2*df.urstar/df.rstar)**2 + (2*df.ua/df.a)**2)
medf = np.median(df.flux)
df_hot = df[df.flux > medf]
df_cold = df[df.flux <= medf]

# %%
ss_names = {"name" : ['Me','V','E','Ma','J','S','U','N']}
ss = pd.DataFrame(ss_names) 
ss['m'] = [0.0553, 0.815, 1.00, 0.107, 317.83, 95.159, 14.536, 17.147]
ss['r'] = [0.383,0.950,1.0, 0.532, 10.973, 9.140, 3.981, 3.865]
ss['a'] = [0.387, 0.723 , 1.0, 1.524, 5.204, 9.582, 19.201, 30.047]
ss['rho'] = (ss.m * mearth)/(4./3 * np.pi * (ss.r * rearth)**3.)
ss['flux'] = 1./ss.a**2
ss['per'] = 365.25 * pow(ss.a, 3./2)
ss = ss.set_index('name')
ss.head()
# Out:
#              m       r      a       rho      flux          per
# name
# Me      0.0553   0.383  0.387  5.435851  6.676949    87.933968
# V       0.8150   0.950  0.723  5.249592  1.913037   224.542043
# E       1.0000   1.000  1.000  5.522539  1.000000   365.250000
# Ma      0.1070   0.532  1.524  3.924530  0.430556   687.175513
# J     317.8300  10.973  5.204  1.328488  0.036925  4336.068720

# %%
len(df)
# Out:
# 247

# %%
sp = df[df.r <= 4.]
sp.sort(inplace=True)
sp.loc[:,['per','m','um','r','ur','flux','orbref']]
# Out:
#                     per          m        um         r        ur         flux  \
# name
# 55 Cnc e       0.736546   8.379902  0.392415  1.990000  0.084000  2439.689702
# CoRoT-7 b      0.853585   7.420000  1.210000  1.580000  0.100000  1779.432902
# GJ 1214 b      1.580405   6.450000  0.910000  2.650000  0.090000    16.320107
# HD 97658 b     9.490900   7.862465  0.730025  2.339998  0.165000    48.105998
# KOI-104.01     2.508060  10.840000  1.400000  3.510000  0.150000   238.747262
# KOI-108.01    15.965400  14.110000  4.700000  3.370000  0.090000   133.152439
# KOI-116.01    13.570800  10.440000  3.200000  2.500000  0.320000    92.172287
# KOI-116.02    43.844500  11.170000  5.800000  2.560000  0.330000    19.298378
# KOI-116.03     6.164860   0.150000  2.800000  0.820000  0.110000   263.942913
# KOI-116.04    23.980200  -6.390000  7.000000  0.950000  0.130000    43.145671
# KOI-122.01    11.523100  13.000000  2.900000  3.420000  0.090000   179.308712
# KOI-123.01     6.481630   1.300000  5.400000  2.370000  0.070000   412.928788
# KOI-123.02    21.222700   2.220000  7.800000  2.520000  0.070000    84.928469
# KOI-1442.01    0.669310   0.060000  1.200000  1.070000  0.020000  3670.035258
# KOI-148.01     4.778000   3.940000  2.100000  1.880000  0.100000   182.732012
# KOI-148.02     9.673950  14.610000  2.300000  2.710000  0.140000    71.340757
# KOI-148.03    42.896100   7.930000  4.600000  2.040000  0.110000     9.793075
# KOI-153.01     8.925070  -4.600000  6.200000  2.190000  0.060000    36.374126
# KOI-153.02     4.754000   7.100000  3.300000  1.820000  0.050000    84.242097
# KOI-1612.01    2.465020   0.480000  3.200000  0.820000  0.030000  1403.574185
# KOI-1925.01   68.958400   2.690000  6.200000  1.190000  0.030000     6.164804
# KOI-244.02     6.238500   9.600000  4.200000  2.710000  0.050000   481.745896
# KOI-245.01    39.792200   1.870000  9.080000  1.940000  0.060000    10.214952
# KOI-245.02    21.302000   3.350000  4.000000  0.750000  0.030000    23.500284
# KOI-245.03    13.367500   2.780000  3.700000  0.320000  0.020000    43.742140
# KOI-246.01     5.398750   5.970000  1.700000  2.330000  0.020000   406.874845
# KOI-246.02     9.605040   2.180000  3.500000  1.000000  0.020000   188.735195
# KOI-261.01    16.238500   8.460000  3.400000  2.670000  0.220000    62.124801
# KOI-283.01    16.092000  16.130000  3.500000  2.410000  0.200000    63.055987
# KOI-283.02    25.516900   8.250000  5.900000  0.840000  0.070000    34.101159
# KOI-292.01     2.586640   3.510000  1.900000  1.480000  0.130000   736.444219
# KOI-299.01     1.541680   3.550000  1.600000  1.990000  0.220000  1535.674313
# KOI-305.01     4.603580   6.150000  1.300000  1.480000  0.080000    99.742864
# KOI-321.01     2.426290   6.350000  1.400000  1.430000  0.030000   739.622386
# KOI-321.02     4.623320   2.710000  1.800000  0.850000  0.030000   313.084610
# KOI-41.01     12.815900   0.850000  4.000000  2.200000  0.050000   189.649523
# KOI-41.02      6.887050   7.340000  3.200000  1.320000  0.040000   434.083142
# KOI-41.03     35.333100  -4.360000  4.100000  1.610000  0.050000    49.057820
# KOI-69.01      4.726740   2.590000  2.000000  1.500000  0.030000   274.895999
# KOI-82.01     16.145700   8.930000  2.000000  2.220000  0.070000    21.079097
# KOI-82.02     10.311700   3.800000  1.800000  1.180000  0.040000    38.325469
# KOI-82.03     27.453600   0.620000  3.300000  0.880000  0.030000    10.386330
# KOI-82.04      7.071420  -1.580000  2.000000  0.580000  0.020000    63.375149
# KOI-82.05      5.286960   0.410000  1.600000  0.470000  0.020000    93.394178
# KOI-94 b       3.743208  10.500000  4.600000  1.710000  0.160000  1193.265629
# Kepler-10 b    0.837495   4.600000  1.260000  1.460000  0.020000  3674.693973
# Kepler-11 b   10.303900   1.899920  1.199948  1.797921  0.040352   125.271106
# Kepler-11 c   13.024100   2.899876  2.249906  2.867437  0.054951    91.598692
# Kepler-11 d   22.684500   7.299707  1.149953  3.117218  0.064942    43.695654
# Kepler-11 f   46.688800   2.297913  1.700001  2.487138  0.054937    16.691612
# Kepler-18 b    3.504725   6.991965  3.495983  2.000018  0.099984   462.243737
# Kepler-20 b    3.696122   8.474453  2.122106  1.908295  0.164853   346.710610
# Kepler-20 c   10.854092  15.733766  3.314223  3.067259  0.254772    82.444687
# Kepler-20 d   77.611840   7.527963  7.218473  2.747545  0.234790     5.984927
# Kepler-30 b   29.334000  11.300605  1.400074  3.896522  0.199821    21.514893
# Kepler-36 b   13.839890   4.461478  0.300773  1.484674  0.034969   217.365219
# Kepler-36 c   16.238550   8.100828  0.531364  3.675716  0.053952   175.645876
# Kepler-68 b    5.398763   8.321392  2.305925  2.307940  0.074933   409.091742
# Kepler-68 c    9.605085   4.812379  3.057857  0.952149  0.039465   189.763836
# Kepler-78 b    0.354167   1.690000  0.410000  1.200000  0.090000  3093.471095
#
#                                 orbref
# name
# 55 Cnc e      Endl 2012, Dragomir 2013
# CoRoT-7 b                  Hatzes 2012
# GJ 1214 b                  Carter 2011
# HD 97658 b               Dragomir 2013
# KOI-104.01                  Marcy 2013
# KOI-108.01                  Marcy 2013
# KOI-116.01                  Marcy 2013
# KOI-116.02                  Marcy 2013
# KOI-116.03                  Marcy 2013
# KOI-116.04                  Marcy 2013
# KOI-122.01                  Marcy 2013
# KOI-123.01                  Marcy 2013
# KOI-123.02                  Marcy 2013
# KOI-1442.01                 Marcy 2013
# KOI-148.01                  Marcy 2013
# KOI-148.02                  Marcy 2013
# KOI-148.03                  Marcy 2013
# KOI-153.01                  Marcy 2013
# KOI-153.02                  Marcy 2013
# KOI-1612.01                 Marcy 2013
# KOI-1925.01                 Marcy 2013
# KOI-244.02                  Marcy 2013
# KOI-245.01                  Marcy 2013
# KOI-245.02                  Marcy 2013
# KOI-245.03                  Marcy 2013
# KOI-246.01                  Marcy 2013
# KOI-246.02                  Marcy 2013
# KOI-261.01                  Marcy 2013
# KOI-283.01                  Marcy 2013
# KOI-283.02                  Marcy 2013
# KOI-292.01                  Marcy 2013
# KOI-299.01                  Marcy 2013
# KOI-305.01                  Marcy 2013
# KOI-321.01                  Marcy 2013
# KOI-321.02                  Marcy 2013
# KOI-41.01                   Marcy 2013
# KOI-41.02                   Marcy 2013
# KOI-41.03                   Marcy 2013
# KOI-69.01                   Marcy 2013
# KOI-82.01                   Marcy 2013
# KOI-82.02                   Marcy 2013
# KOI-82.03                   Marcy 2013
# KOI-82.04                   Marcy 2013
# KOI-82.05                   Marcy 2013
# KOI-94 b                    Weiss 2013
# Kepler-10 b        Fogtmann-Shulz 2013
# Kepler-11 b              Lissauer 2013
# Kepler-11 c              Lissauer 2013
# Kepler-11 d              Lissauer 2013
# Kepler-11 f              Lissauer 2013
# Kepler-18 b               Cochran 2011
# Kepler-20 b               Gautier 2012
# Kepler-20 c               Gautier 2012
# Kepler-20 d               Gautier 2012
# Kepler-30 b         Sanchis-Ojeda 2012
# Kepler-36 b                Carter 2012
# Kepler-36 c                Carter 2012
# Kepler-68 b             Gilliland 2013
# Kepler-68 c             Gilliland 2013
# Kepler-78 b       Sanchis-Ojeda (2013)

# %%
df.to_csv('exoplanet_table_full.csv')
df.to_pickle('exoplanets.pickle')
sp_cut = sp.ix[:,['m','um','r','ur','rho','urho','firstref','orbref']]
sp_cut.to_csv('small_exoplanets.csv')
sp.to_pickle('small_exoplanets.pickle')

# %%
len(sp)
# Out:
# 60

# %%
sort(sp.urstar/sp.rstar)*100.
# Out:
# name
# Kepler-10 b      0.845070
# 55 Cnc e         1.060445
# Kepler-36 b      1.168512
# Kepler-36 c      1.168512
# KOI-244.02       1.526718
# Kepler-68 c      1.528560
# Kepler-68 b      1.528560
# KOI-246.02       1.612903
# KOI-246.01       1.612903
# Kepler-11 f      1.830986
# Kepler-11 d      1.830986
# Kepler-11 c      1.830986
# Kepler-11 b      1.830986
# KOI-321.01       1.869159
# KOI-321.02       1.869159
# KOI-69.01        2.173913
# KOI-1925.01      2.247191
# KOI-1612.01      2.439024
# KOI-41.02        2.684564
# KOI-41.03        2.684564
# KOI-41.01        2.684564
# KOI-82.02        2.702703
# KOI-82.05        2.702703
# KOI-82.04        2.702703
# KOI-82.03        2.702703
# KOI-82.01        2.702703
# KOI-108.01       2.777778
# KOI-122.01       2.836879
# KOI-153.01       2.898551
# KOI-153.02       2.898551
# KOI-123.02       3.030303
# KOI-123.01       3.030303
# KOI-245.02       3.896104
# KOI-245.01       3.896104
# KOI-245.03       3.896104
# KOI-104.01       3.947368
# GJ 1214 b        4.597156
# CoRoT-7 b        4.597701
# Kepler-18 b      4.602888
# HD 97658 b       5.192034
# KOI-305.01       5.479452
# KOI-148.03       5.617978
# KOI-148.02       5.617978
# KOI-148.01       5.617978
# KOI-1442.01      6.930693
# Kepler-20 b      8.209746
# Kepler-20 c      8.209746
# Kepler-20 d      8.209746
# KOI-261.01       8.823529
# KOI-292.01       9.183673
# KOI-94 b         9.210526
# KOI-283.02       9.708738
# KOI-283.01       9.708738
# KOI-299.01      10.810811
# Kepler-78 b     12.162162
# Kepler-30 b     12.631579
# KOI-116.04      16.346154
# KOI-116.03      16.346154
# KOI-116.02      16.346154
# KOI-116.01      16.346154
# Length: 60, dtype: float64
