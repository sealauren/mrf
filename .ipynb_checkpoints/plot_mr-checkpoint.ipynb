# %%
# %pylab inline
import pickle
import numpy as np
import scipy as sp
import pandas as pd
from astropy import constants as const
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pickle.load(open('exoplanets.pickle'))
medf = np.median(df.flux)
df_hot = df[df.flux > medf]
df_cold = df[df.flux <= medf]
sp = pickle.load(open('small_exoplanets.pickle'))
sp = sp.ix[sp.index!='Kepler-78 b',:]
sp['evap'] = sp.flux * sp.age
sp.um = np.maximum(sp.um,0.1*sp.m)
sp.ur = np.maximum(sp.ur,0.05*sp.r)
sp.urho = np.maximum(abs(sp.urho), (np.sqrt((sp.um/sp.m)**2. + (3*sp.ur/sp.r)**2.)*sp.rho))
sp_clean = sp[sp.urho < 6.5]
sp_1sig = sp[sp.m > sp.um]
sp_cold = sp[sp.flux <= np.median(sp.flux)]
sp_hot = sp[sp.flux > np.median(sp.flux)]
ttvs = sp.ix[['Kepler-11 b','Kepler-11 c','Kepler-11 d','Kepler-11 f','Kepler-30 b','Kepler-36 b','Kepler-36 c'],:]
#len(sp)

# %%
sp.ix[:,['per','m','um','r','ur','rho','urho','orbref']]
# Out:
#                     per          m        um         r        ur        rho  \
# name
# 55 Cnc e       0.736546   8.379902  0.837990  2.173000  0.108650    4.17300
# CoRoT-7 b      0.853585   7.420000  1.210000  1.580000  0.100000    6.23249
# GJ 1214 b      1.580405   6.450000  0.910000  2.650000  0.132500    1.87000
# HD 97658 b     9.490900   7.862465  0.786247  2.339998  0.165000    3.44000
# KOI-104.01     2.508060  10.840000  1.400000  3.510000  0.175500    1.45000
# KOI-108.01    15.965400  14.110000  4.700000  3.370000  0.168500    2.02000
# KOI-116.01    13.570800  10.440000  3.200000  2.500000  0.320000    3.28000
# KOI-116.02    43.844500  11.170000  5.800000  2.560000  0.330000    3.10000
# KOI-116.03     6.164860   0.150000  2.800000  0.820000  0.110000    1.26000
# KOI-116.04    23.980200  -6.390000  7.000000  0.950000  0.130000  -41.00000
# KOI-122.01    11.523100  13.000000  2.900000  3.420000  0.171000    1.71000
# KOI-123.01     6.481630   1.300000  5.400000  2.370000  0.118500    0.30000
# KOI-123.02    21.222700   2.220000  7.800000  2.520000  0.126000    0.65000
# KOI-1442.01    0.669310   0.060000  1.200000  1.070000  0.053500    0.29000
# KOI-148.01     4.778000   3.940000  2.100000  1.880000  0.100000    3.23000
# KOI-148.02     9.673950  14.610000  2.300000  2.710000  0.140000    4.01000
# KOI-148.03    42.896100   7.930000  4.600000  2.040000  0.110000    5.08000
# KOI-153.01     8.925070  -4.600000  6.200000  2.190000  0.109500   -2.44000
# KOI-153.02     4.754000   7.100000  3.300000  1.820000  0.091000    6.60000
# KOI-1612.01    2.465020   0.480000  3.200000  0.820000  0.041000    4.42000
# KOI-1925.01   68.958400   2.690000  6.200000  1.190000  0.059500    8.88000
# KOI-244.02     6.238500   9.600000  4.200000  2.710000  0.135500    2.50000
# KOI-245.01    39.792200   1.870000  9.080000  1.940000  0.097000    1.30000
# KOI-245.02    21.302000   3.350000  4.000000  0.750000  0.037500   44.33000
# KOI-245.03    13.367500   2.780000  3.700000  0.320000  0.020000  548.80000
# KOI-246.01     5.398750   5.970000  1.700000  2.330000  0.116500    2.60000
# KOI-246.02     9.605040   2.180000  3.500000  1.000000  0.050000   10.77000
# KOI-261.01    16.238500   8.460000  3.400000  2.670000  0.220000    2.26000
# KOI-283.01    16.092000  16.130000  3.500000  2.410000  0.200000    6.00000
# KOI-283.02    25.516900   8.250000  5.900000  0.840000  0.070000   77.70000
# KOI-292.01     2.586640   3.510000  1.900000  1.480000  0.130000    5.44000
# KOI-299.01     1.541680   3.550000  1.600000  1.990000  0.220000    2.18000
# KOI-305.01     4.603580   6.150000  1.300000  1.480000  0.080000   10.90000
# KOI-321.01     2.426290   6.350000  1.400000  1.430000  0.071500   11.82000
# KOI-321.02     4.623320   2.710000  1.800000  0.850000  0.042500   24.39000
# KOI-41.01     12.815900   0.850000  4.000000  2.200000  0.110000    0.35000
# KOI-41.02      6.887050   7.340000  3.200000  1.320000  0.066000   14.25000
# KOI-41.03     35.333100  -4.360000  4.100000  1.610000  0.080500   -5.72000
# KOI-69.01      4.726740   2.590000  2.000000  1.500000  0.075000    4.17000
# KOI-82.01     16.145700   8.930000  2.000000  2.220000  0.111000    4.68000
# KOI-82.02     10.311700   3.800000  1.800000  1.180000  0.059000   13.27000
# KOI-82.03     27.453600   0.620000  3.300000  0.880000  0.044000    4.92000
# KOI-82.04      7.071420  -1.580000  2.000000  0.580000  0.029000  -44.24000
# KOI-82.05      5.286960   0.410000  1.600000  0.470000  0.023500   23.29000
# KOI-94 b       3.743208  10.500000  4.600000  1.710000  0.160000   10.10000
# Kepler-10 b    0.837495   4.539184  1.248482  1.415997  0.070800    8.80000
# Kepler-11 b   10.303900   1.899920  1.199948  1.797921  0.089896    1.72000
# Kepler-11 c   13.024100   2.899876  2.249906  2.867437  0.143372    0.66000
# Kepler-11 d   22.684500   7.299707  1.149953  3.117218  0.155861    1.28000
# Kepler-11 f   46.688800   2.297913  1.700001  2.487138  0.124357    0.69000
# Kepler-18 b    3.504725   6.991965  3.495983  2.000018  0.100001    4.90000
# Kepler-20 b    3.696122   8.474453  2.122106  1.908295  0.164853    6.50000
# Kepler-20 c   10.854092  15.733766  3.314223  3.067259  0.254772    2.91000
# Kepler-20 d   77.611840   7.527963  7.218473  2.747545  0.234790    2.03500
# Kepler-30 b   29.334000  11.300605  1.400074  3.896522  0.199821    1.02000
# Kepler-36 b   13.839890   4.461478  0.446148  1.484674  0.074234    7.46000
# Kepler-36 c   16.238550   8.100828  0.810083  3.675716  0.183786    0.89000
# Kepler-68 b    5.398763   8.321392  2.305925  2.307940  0.115397    3.32000
# Kepler-68 c    9.605085   4.812379  3.057857  0.952149  0.047607   28.00000
#
#                     urho              orbref
# name
# 55 Cnc e        0.752298           Endl 2012
# CoRoT-7 b       1.559924         Hatzes 2012
# GJ 1214 b       0.400000         Carter 2011
# HD 97658 b      0.865000       Dragomir 2013
# KOI-104.01      0.287012          Marcy 2013
# KOI-108.01      0.737932          Marcy 2013
# KOI-116.01      1.611567          Marcy 2013
# KOI-116.02      2.070000          Marcy 2013
# KOI-116.03     26.260000          Marcy 2013
# KOI-116.04     39.750000          Marcy 2013
# KOI-122.01      0.459679          Marcy 2013
# KOI-123.01      2.200000          Marcy 2013
# KOI-123.02      2.300000          Marcy 2013
# KOI-1442.01     5.800163          Marcy 2013
# KOI-148.01      1.840000          Marcy 2013
# KOI-148.02      0.910000          Marcy 2013
# KOI-148.03      3.120000          Marcy 2013
# KOI-153.01      2.700000          Marcy 2013
# KOI-153.02      3.223399          Marcy 2013
# KOI-1612.01    29.820000          Marcy 2013
# KOI-1925.01    20.600000          Marcy 2013
# KOI-244.02      1.156250          Marcy 2013
# KOI-245.01      6.315311          Marcy 2013
# KOI-245.02     53.600000          Marcy 2013
# KOI-245.03    737.629848          Marcy 2013
# KOI-246.01      0.836807          Marcy 2013
# KOI-246.02     17.366587          Marcy 2013
# KOI-261.01      1.110000          Marcy 2013
# KOI-283.01      1.981506          Marcy 2013
# KOI-283.02     58.864696          Marcy 2013
# KOI-292.01      3.480000          Marcy 2013
# KOI-299.01      1.219888          Marcy 2013
# KOI-305.01      2.903965          Marcy 2013
# KOI-321.01      3.151933          Marcy 2013
# KOI-321.02     16.607969          Marcy 2013
# KOI-41.01       1.650000          Marcy 2013
# KOI-41.02       6.569968          Marcy 2013
# KOI-41.03       6.000000          Marcy 2013
# KOI-69.01       3.290000          Marcy 2013
# KOI-82.01       1.261518          Marcy 2013
# KOI-82.02       6.593424          Marcy 2013
# KOI-82.03      26.197494          Marcy 2013
# KOI-82.04      56.700000          Marcy 2013
# KOI-82.05      94.930000          Marcy 2013
# KOI-94 b        5.500000          Weiss 2013
# Kepler-10 b     2.756944        Batalha 2011
# Kepler-11 b     1.116532       Lissauer 2013
# Kepler-11 c     0.521552       Lissauer 2013
# Kepler-11 d     0.278432       Lissauer 2013
# Kepler-11 f     0.520851       Lissauer 2013
# Kepler-18 b     2.557875        Cochran 2011
# Kepler-20 b     2.350000        Gautier 2012
# Kepler-20 c     0.965000        Gautier 2012
# Kepler-20 d     2.035000        Gautier 2012
# Kepler-30 b     0.201481  Sanchis-Ojeda 2012
# Kepler-36 b     1.344871         Carter 2012
# Kepler-36 c     0.160447         Carter 2012
# Kepler-68 b     1.046137      Gilliland 2013
# Kepler-68 c    18.280631      Gilliland 2013

# %%
ttvs.ix[:,['rho','urho']]
# Out:
#               rho      urho
# Kepler-11 b  1.72  1.116532
# Kepler-11 c  0.66  0.521552
# Kepler-11 d  1.28  0.278432
# Kepler-11 f  0.69  0.520851
# Kepler-30 b  1.02  0.201481
# Kepler-36 b  7.46  1.344871
# Kepler-36 c  0.89  0.160447

# %%
mearth = 5.9721986E27 #grams
rearth = 6.3675E8 #centimeters
msun = 1.988435E33 #grams
rsun = 6.955E10 #centimeters
cmperau=1.496E13
lsun = 3.846E33 #ergs per second
tsun = 5780 #kelvins
ss_names = {"name" : ['Me','V','E','Ma','J','S','U','N']}
ss = pd.DataFrame(ss_names) 
ss['m'] = [0.0553, 0.815, 1.00, 0.107, 317.83, 95.159, 14.536, 17.147]
ss['r'] = [0.383,0.950,1.0, 0.532, 10.973, 9.140, 3.981, 3.865]
ss['a'] = [0.387, 0.723 , 1.0, 1.524, 5.204, 9.582, 19.201, 30.047]
ss['rho'] = (ss.m * mearth)/(4./3 * np.pi * (ss.r * rearth)**3.)
ss['flux'] = 1./ss.a**2
ss['per'] = 365.25 * pow(ss.a, 3./2)
ss = ss.set_index('name')
ss.head()
# Out:
#              m       r      a       rho      flux          per
# name
# Me      0.0553   0.383  0.387  5.435851  6.676949    87.933968
# V       0.8150   0.950  0.723  5.249592  1.913037   224.542043
# E       1.0000   1.000  1.000  5.522539  1.000000   365.250000
# Ma      0.1070   0.532  1.524  3.924530  0.430556   687.175513
# J     317.8300  10.973  5.204  1.328488  0.036925  4336.068720

# %%
# plot whole population in r vs. m, d vs. m
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1, xscale="log", yscale="log") 
ax2 = fig.add_subplot(1,2,2, xscale="log", yscale="log") 
ax1.errorbar(df_hot.m, df_hot.r, xerr=df_hot.um, yerr=df_hot.ur, 
             fmt='o', markersize=5, 
             alpha=0.5, color='r', label='$F > $ %i $F_E$'%medf, 
             capsize=0);
ax1.errorbar(df_cold.m, df_cold.r, xerr=df_cold.um, yerr=df_cold.ur, 
             fmt='o', markersize=5, 
             alpha =0.5, color='b', label='$F < $ %i $F_E$'%medf, 
             capsize=0);
for x in zip(ss.m,ss.r,ss.index):
    ax1.text(x[0], x[1], x[2], fontsize=12, family='monospace', color='k')
ax2.errorbar(df_hot.m, df_hot.rho, xerr=df_hot.um, yerr=df_hot.urho, 
             fmt='o', markersize=5, 
             alpha=0.5, color='r', label='$F > $ %i $F_E$'%medf, 
             capsize=0);
ax2.errorbar(df_cold.m, df_cold.rho, xerr=df_cold.um, yerr=df_cold.urho, 
             fmt='o', markersize=5, 
             alpha=0.5, color='b', label='$F < $ %i $F_E$'%medf,
             capsize=0);
for x in zip(ss.m,ss.rho,ss.index):
    ax2.text(x[0], x[1], x[2], fontsize=12, family='monospace', color='k')
ax1.set_xlabel('Planet Mass ($\mathrm{M_E}$)', fontsize=16)
ax2.set_xlabel('Planet Mass ($\mathrm{M_E}$)', fontsize=16)
ax1.set_ylabel('Planet Radius ($\mathrm{R_E}$)',fontsize=16)
ax2.set_ylabel('Planet Density (g/cc)',fontsize=16)
ax1.legend(loc='lower right');
ax2.legend(loc='upper right');
fig.set_size_inches(12,6)
plt.savefig('mrf.eps')

# %%
# numerical weighted linear fit
fitfunc = lambda p, x: p[0] + p[1] * x
errfunc = lambda p, x, y, err: (y - fitfunc(p, x)) / err  
from scipy.optimize import leastsq
out = leastsq(errfunc,  [0.2,2.5], args=(sp.r, sp.m, sp.um),full_output=1)
print "Best parameters:", out[0]
print "Covariance:", out[1]
print "Chi^2:", (errfunc(out[0],sp.r,sp.m,sp.um)**2.).sum()/(len(sp.m) - len(out[0]))
best_pars = out[0]
rarr = linspace(0.0, 4.0, 101)
marr = fitfunc(best_pars,rarr)
darr = (marr*mearth)/(4./3.*pi*(rarr*rearth)**3)
darr[darr < 0] = 100
from scipy.stats import linregress
# Out:
# Best parameters: [ 0.45229022  2.62713362]
# Covariance: [[ 0.30388487 -0.12817734]
#  [-0.12817734  0.06335073]]
# Chi^2: 1.98331515426

# %%
# calculated predict masses, densities
rpred = (sp.m - best_pars[0])/best_pars[1]
mpred = fitfunc(best_pars,sp.r)
dpred = mpred*mearth/(4./3.*(rpred*rearth)**3.)
r_resid = sp.r - rpred
m_resid = sp.m - mpred
d_resid = sp.rho - dpred
rms = np.sqrt(np.mean(m_resid**2))
print rms
# Out:
# 3.88260137792

# %%
# this is an analytical reformulation of the mass-radius fit for density vs. radius
fitfunc2 = lambda p, x: p[0] * pow(x,-3.) + p[1] * pow(x,-2.)
errfunc2 = lambda p, x, y, err: (y - fitfunc2(p, x)) / err   
out2 = leastsq(errfunc2,  [2.5,2.5], args=(sp.r, sp.rho, sp.urho),full_output=1)
print "Best parameters:", out2[0]
print "Covariance:", out2[1]
print "Chi^2:", (errfunc2(out2[0],sp.r,sp.rho,sp.urho)**2.).sum()/(len(sp.rho) - len(out2[0]))
best_pars_d = out2[0]
darr2 = best_pars_d[0]/rarr**3. + best_pars_d[1]/rarr**2.
# Out:
# Best parameters: [ -1.84580933  14.78137991]
# Covariance: [[ 14.98057237  -6.73583459]
#  [ -6.73583459   3.59115547]]
# Chi^2: 1.3526462343

# %%
# this is a *numerical* weighted polynomial fit to density vs. radius
fitfunc3 = lambda p, x: p[0] + p[1] * x * p[2] * x**2.
errfunc3 = lambda p, x, y, err: (y - fitfunc3(p, x)) / err
out3 = leastsq(errfunc3,  [16.2,-8.69,1.23], args=(sp_clean.r, sp_clean.rho, sp_clean.urho),full_output=1, xtol=4)
print "Best parameters:", out3[0]
print "Covariance:", out3[1]
print "Chi^2:", (errfunc3(out3[0],sp_clean.r,sp_clean.rho,sp_clean.urho)**2).sum()/(len(sp_clean.rho) - len(out3[0]))
best_q = out3[0]
darr3 = best_q[0] + best_q[1] * rarr + best_q[2] * rarr**2.
# Out:
# Best parameters: [ 16.2   -8.69   1.23]
# Covariance: [[  5.86858011e-02   8.89123098e-01   1.25992608e-01]
#  [  8.89906448e-01   1.98792361e+10   2.81374689e+09]
#  [  1.26103485e-01   2.81374689e+09   3.98263369e+08]]
# Chi^2: 616933.087272

# %%
# this is an *analytical* weighted polynomial fit to density vs. radius -- the best!
out4 = np.polynomial.polynomial.polyfit(sp.r, sp.rho, 2, rcond=None, full=True, w=1./sp.urho**2.)
best_q = out4[0]
darr3 = best_q[0] + best_q[1] * rarr + best_q[2] * rarr**2.# + best_q[3] * rarr**3.
rho_pred = best_q[0] + best_q[1] * sp.r + best_q[2] * sp.r**2.# + best_q[3] * sp.r**3.
print "Best parameters:", out4[0]
print "Covariance:", out4[1]
print "Chi^2:", (((sp.rho - rho_pred)/sp.urho)**2.).sum()/(len(sp.rho) - len(out4[0]))
# Out:
# Best parameters: [ 10.34791029  -4.95591058   0.65369191]
# Covariance: [array([ 121.94015935]), 3, array([ 1.72951428,  0.09358679,  0.00467524]), 1.3100631690576847e-14]
# Chi^2: 1.58418869899

# %%
powerlaw = lambda p, x: p[0] * pow(x,p[1])
errfunc_plaw = lambda p, x, y, err : (y - powerlaw(p, x))/err

mass_plaw = leastsq(errfunc_plaw,  [3.,1.], 
              args=(sp.r, sp.m, sp.um),full_output=1)
mpars = mass_plaw[0]
mplaw = mpars[0] * pow(rarr,mpars[1])
print "Mass Power Law Solution:"
print "Best parameters:", mpars
print "Covariance:", mass_plaw[1]
print "Chi^2:", (errfunc_plaw(mpars,sp.r,sp.m,sp.um)**2.).sum()/(len(sp.m) - len(mpars))
density_plaw = leastsq(errfunc_plaw,  [8.,-1.], 
                       args=(sp.r, sp.rho, sp.urho),full_output=1)
dpars = density_plaw[0]
dplaw = dpars[0] * pow(rarr,dpars[1])
print "********************************"
print "Density Power Law Solution:"
print "Best parameters:", dpars
print "Covariance:", density_plaw[1]
print "Chi^2:", (errfunc_plaw(dpars,sp.r,sp.rho,sp.urho)**2.).sum()/(len(sp.m) - len(dpars))
rocky_plaw = leastsq(errfunc_plaw,  [3.,1.], 
              args=(sp[sp.r < 1.5].r, sp[sp.r < 1.5].m, sp[sp.r < 1.5].um),full_output=1)
rocky_pars = rocky_plaw[0]
rocky_r = arange(0.01,1.5,0.01)
rockplaw = rocky_pars[0] * pow(rocky_r,rocky_pars[1])
print "********************************"
print "Rocky Mass Power Law Solution:"
print "Best parameters:", rocky_pars
print "Covariance:", rocky_plaw[1]
print "Chi^2:", (errfunc_plaw(rocky_pars,
                              sp[sp.r < 1.5].r,sp[sp.r < 1.5].m,
                              sp[sp.r < 1.5].um)**2.).sum()/(len(sp[sp.r < 1.5].m) - len(rocky_pars))
# Out:
# Mass Power Law Solution:
# Best parameters: [ 3.17184921  0.87198702]
# Covariance: [[ 0.08222481 -0.02473762]
#  [-0.02473762  0.00868191]]
# Chi^2: 1.95977373665
# Density Power Law Solution:
# Best parameters: [ 13.51963972  -1.96402695]
# Covariance: [[ 3.65333213 -0.26229359]
#  [-0.26229359  0.0220138 ]]
# Chi^2: 1.35555067776
# Rocky Mass Power Law Solution:
# Best parameters: [ 1.75138718  2.54221105]
# Covariance: [[ 0.49624584 -0.72890834]
#  [-0.72890834  1.11263119]]
# Chi^2: 0.821537992398

# %%
# bin mass, radius, density
rwm, rwd, urw, mw, umw, rhow, urhow = [], [], [], [], [], [], []
for r in arange(0,4.,0.5):
    rbin = sp.loc[r <= sp.r].loc[sp.r < r+0.5]
    rwm.append(np.average(rbin['r'], weights = (1./rbin.um**2.)))
    rwd.append(np.average(rbin['r'], weights = (1./rbin.urho**2.)))
    mw.append(np.average(rbin['m'], weights = 1./rbin.um**2.))
    rhow.append(np.average(rbin['rho'], weights = 1./rbin.urho**2.))
    urw.append(std(rbin.r)/sqrt(len(rbin)))
    umw.append(std(rbin.m)/sqrt(len(rbin)))
    urhow.append(std(rbin.rho)/sqrt(len(rbin)))
means = pd.DataFrame({'r_m':rwm, 'r_d':rwd, 'ur':urw, 'm':mw, 'um':umw, 'rho':rhow, 'urho':urhow})

# %%
# plot mass, density vs. radius
fig = plt.figure()
pylab.sharex=True
ax1 = fig.add_subplot(1,2,1)
ax1.errorbar(sp.r, sp.m, xerr=sp.ur, yerr=sp.um, fmt='o', markersize=5, 
             alpha =0.3, color='k', capsize=0, elinewidth=2); # black option
ax1.errorbar(means.r_m,means.m, xerr=means.ur, yerr=means.um, 
             markersize=10, marker='s',fmt='o', capsize=0, elinewidth=4, alpha = 0.8)
ax1.plot(rarr, marr, '--k', linewidth=4, label=("M = %.1f + %.1f R" % (best_pars[0], best_pars[1])))
ax1.plot(rarr, mplaw, '--r', linewidth=4, label=("M = %.1f * R^ %.1f"% (mpars[0], mpars[1])))
ax1.plot(rocky_r, rockplaw, '--c', linewidth=4, label=("M = %.1f * R^ %.1f"% (rocky_pars[0], rocky_pars[1])))
#ax1.errorbar(ttvs.r, ttvs.m, xerr=ttvs.ur, yerr=ttvs.um, fmt='o',capsize=0, elinewidth=2, alpha=0.5, color='orange', label=('TTVs'))
ax1.set_xlabel('Planet Radius ($\mathrm{R_E}$)',fontsize=24)
ax1.set_ylabel('Planet Mass ($\mathrm{M_E})$',fontsize=24)
for x in zip(ss.r,ss.m,ss.index):
    if (x[1] < 20) and (x[1] > -3) and (x[0] < 4.):
        ax1.text(x[0], x[1], x[2], fontsize=12, family='monospace', color='m')
ax1.legend(loc='upper left');
pyplot.axis([0.0,4.1,-3,20])

ax2 = fig.add_subplot(1,2,2)
ax2.errorbar(sp.r, sp.rho, xerr=sp.ur, yerr=sp.urho, fmt='o', markersize=5, 
             alpha=0.3, color='k',capsize=0, elinewidth=2);
ax2.plot(rarr, darr3, '--k', linewidth=4, label=("Rho = %.1f + %.1f R + %.1f R^2" % (best_q[0], best_q[1], best_q[2])))
ax2.plot(rarr, dplaw, '--r', linewidth=4, label=("Rho = %.2f * R^ %.1f"% (dpars[0], dpars[1])))
ax2.set_xlabel('Planet Radius ($\mathrm{R_E}$)',fontsize=24)
ax2.set_ylabel('Planet Density ($\mathrm{g/cm^{3}}$)',fontsize=24)
ax2.text(2.5, 6, 'Earth Density', fontsize=12, family='monospace')
ax2.errorbar(means.r_d,means.rho, xerr=means.ur, yerr=means.urho, 
             markersize=10, marker='s', fmt='o', capsize=0, elinewidth=4, alpha=0.8)
#ax2.errorbar(ttvs.r, ttvs.rho, xerr=ttvs.ur, yerr=ttvs.urho, fmt='o',capsize=0, elinewidth=2, alpha=0.5, color='orange',label=('TTVs'))
#ax2.errorbar(sp.ix['Kepler-78 b','r'], sp.ix['Kepler-78 b','rho'], 
#             xerr=sp.ix['Kepler-78 b','ur'], yerr=sp.ix['Kepler-78 b','urho'], fmt='o',capsize=0, elinewidth=4, 
#             alpha=0.5, color='r')
ax2.axhline(y=5.52, linewidth=4, color='g', linestyle='-.')
for x in zip(ss.r,ss.rho,ss.index):
    if (x[1] < 30) and (x[1] > -1) and (x[0] < 4.) and (x[0] > .9):
        ax2.text(x[0], x[1], x[2], fontsize=12, family='monospace', color='m')
pyplot.axis([0.,4.0,-5,40])
ax2.legend();

fig.set_size_inches(12,6)
subplots_adjust(wspace=0.3)
subplots_adjust(hspace=0.2)
plt.savefig('mr_small.png', dpi=100)
plt.show()

# %%
ordered_d = sp.sort('rt')
print ordered_d.ix[:,['r','rho','urho']]
# Out:
#                      r        rho        urho
# name
# KOI-245.03    0.320000  548.80000  737.629848
# KOI-82.05     0.470000   23.29000   94.930000
# KOI-82.04     0.580000  -44.24000   56.700000
# KOI-245.02    0.750000   44.33000   53.600000
# KOI-116.03    0.820000    1.26000   26.260000
# KOI-1612.01   0.820000    4.42000   29.820000
# KOI-283.02    0.840000   77.70000   58.864696
# KOI-321.02    0.850000   24.39000   16.607969
# KOI-82.03     0.880000    4.92000   26.197494
# KOI-116.04    0.950000  -41.00000   39.750000
# Kepler-68 c   0.952149   28.00000   18.280631
# KOI-246.02    1.000000   10.77000   17.366587
# KOI-1442.01   1.070000    0.29000    5.800163
# KOI-82.02     1.180000   13.27000    6.593424
# KOI-1925.01   1.190000    8.88000   20.600000
# Kepler-78 b   1.200000    5.30000    1.800000
# KOI-41.02     1.320000   14.25000    6.569968
# Kepler-10 b   1.415997    8.80000    2.756944
# KOI-321.01    1.430000   11.82000    3.151933
# KOI-292.01    1.480000    5.44000    3.480000
# KOI-305.01    1.480000   10.90000    2.903965
# Kepler-36 b   1.484674    7.46000    1.344871
# KOI-69.01     1.500000    4.17000    3.290000
# CoRoT-7 b     1.580000    6.23249    1.559924
# KOI-41.03     1.610000   -5.72000    6.000000
# KOI-94 b      1.710000   10.10000    5.500000
# Kepler-11 b   1.797921    1.72000    1.116532
# KOI-153.02    1.820000    6.60000    3.223399
# KOI-148.01    1.880000    3.23000    1.840000
# Kepler-20 b   1.908295    6.50000    2.350000
# KOI-245.01    1.940000    1.30000    6.315311
# KOI-299.01    1.990000    2.18000    1.219888
# Kepler-18 b   2.000018    4.90000    2.557875
# KOI-148.03    2.040000    5.08000    3.120000
# 55 Cnc e      2.173000    4.17300    0.752298
# KOI-153.01    2.190000   -2.44000    2.700000
# KOI-41.01     2.200000    0.35000    1.650000
# KOI-82.01     2.220000    4.68000    1.261518
# Kepler-68 b   2.307940    3.32000    1.046137
# KOI-246.01    2.330000    2.60000    0.836807
# HD 97658 b    2.339998    3.44000    0.865000
# KOI-123.01    2.370000    0.30000    2.200000
# KOI-283.01    2.410000    6.00000    1.981506
# Kepler-11 f   2.487138    0.69000    0.520851
# KOI-116.01    2.500000    3.28000    1.611567
# KOI-123.02    2.520000    0.65000    2.300000
# KOI-116.02    2.560000    3.10000    2.070000
# GJ 1214 b     2.650000    1.87000    0.400000
# KOI-261.01    2.670000    2.26000    1.110000
# KOI-148.02    2.710000    4.01000    0.910000
# KOI-244.02    2.710000    2.50000    1.156250
# Kepler-20 d   2.747545    2.03500    2.035000
# Kepler-11 c   2.867437    0.66000    0.521552
# Kepler-20 c   3.067259    2.91000    0.965000
# Kepler-11 d   3.117218    1.28000    0.278432
# KOI-108.01    3.370000    2.02000    0.737932
# KOI-122.01    3.420000    1.71000    0.459679
# KOI-104.01    3.510000    1.45000    0.287012
# Kepler-36 c   3.675716    0.89000    0.160447
# Kepler-30 b   3.896522    1.02000    0.201481

# %%
rpred = (sp.m - best_pars[0])/best_pars[1]
mpred = fitfunc(best_pars,sp.r)
dpred = mpred*mearth/(4./3.*(rpred*rearth)**3.)
r_resid = (sp.r - rpred) / sp.um
m_resid = (sp.m - mpred) / sp.um
d_resid = (sp.rho - dpred) / sp.urho
#rms = np.sqrt(np.mean(m_resid**2))
#print rms

# %%
#%matplotlib osx
fig = plt.figure(figsize=(8,8));
ax = fig.add_subplot(111,xscale='log');
rho_resid = sp.rho - rho_pred
#notnan = numpy.logical_not(numpy.isnan(sp.flux))
ax.errorbar(sp_clean.flux, sp_clean.rho, 
            xerr=sp_clean.uflux, yerr=sp_clean.urho, 
            fmt='o', alpha = 0.5, capsize=0);
ax.set_xlabel('Flux (Earth flux)', fontsize=18);
ax.set_ylabel('Planet Density (g/cc)', fontsize=18);
pyplot.axis([0,4000,-5,15])
fig.show();
pearsonr(sp_clean.flux, sp_clean.rho)
# Out:
# (0.24841826682745585, 0.099876197148952572)

# %%
#plot residuals
fig = plt.figure(figsize=(14,14));
xarr = [sp.per, sp.a, sp.flux, sp.mstar, sp.rstar, sp.logg, sp.fe, sp.age, sp.vsini]
xarr_err = [None, sp.ua, sp.uflux, sp.umstar, sp.urstar, 
            None, sp.ufe, None, None]
xtit = ['Period (d)','a (AU)','Flux (Earth)',
        '$M_\star$ ($\mathrm{M_{Sun}}$)','$R_\star$ ($\mathrm{R_{Sun}}$)','log(g)',
        '[Fe/H]','Age (Gyr)','Vsini (km/s)']
xscale = ['log','log','log','linear','linear','linear','linear','linear','log']
fig, axarr = plt.subplots(3, 3, sharey=True);
yarr = m_resid
yarr_err = sp.um
for i in xrange(0,3):
    for j in xrange(0,3):
        xs = xarr[3*i + j]
        xerr = xarr_err[3*i + j]
        notnan = np.logical_not(np.isnan(xs))
        xs = xs[notnan]
        ys = yarr[notnan]
        yerr = yarr_err[notnan]
        if xerr is not None: xerr = xerr[notnan]
        axarr[i,j].errorbar(xs,ys, xerr=xerr, yerr=yerr, alpha = 0.5, marker='o', fmt='o')
        if xscale[3*i + j]=='log': axarr[i,j].set_xscale('log')
        if j==0: axarr[i,j].set_ylabel('Residual Mass ($\mathrm{M_E}$)', fontsize=16)
        axarr[i,j].set_xlabel(xtit[3*i+j], fontsize=16)
fig.set_size_inches(12,12);
subplots_adjust(wspace=0.1)
subplots_adjust(hspace=0.5)
#fig.ylabel('Residual Mass')
fig.show();
plt.savefig('mr_resids.png',dpi=100)

# %%
r = []
for x in xarr:
    print x
    notnan = np.logical_not(np.isnan(x))
    rx = pearsonr(x[notnan], m_resid(notnan))
    print rx
    r.append(rx)
pearsonr(sp[notnan].fe, rho_resid[notnan])
out = leastsq(errfunc,  [0.,10], 
              args=(sp[notnan].fe, sp[notnan].rho, sp[notnan].urho),full_output=1)
out[0]   
#[r.append(pearsonr(x[np.logical_not(np.isnan(x))],m_resid[np.logical_not(np.isnan(x)) for x in xarr]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-556-c3d4dde6bf9c> in <module>()
#       3     print x
#       4     notnan = np.logical_not(np.isnan(x))
# ----> 5     rx = pearsonr(x[notnan], m_resid(notnan))
#       6     print rx
#       7     r.append(rx)
#
# TypeError: 'Series' object is not callable
# name
# 55 Cnc e         0.736546
# CoRoT-7 b        0.853585
# GJ 1214 b        1.580405
# HD 97658 b       9.490900
# KOI-104.01       2.508060
# KOI-108.01      15.965400
# KOI-116.01      13.570800
# KOI-116.02      43.844500
# KOI-116.03       6.164860
# KOI-116.04      23.980200
# KOI-122.01      11.523100
# KOI-123.01       6.481630
# KOI-123.02      21.222700
# KOI-1442.01      0.669310
# KOI-148.01       4.778000
# KOI-148.02       9.673950
# KOI-148.03      42.896100
# KOI-153.01       8.925070
# KOI-153.02       4.754000
# KOI-1612.01      2.465020
# KOI-1925.01     68.958400
# KOI-244.02       6.238500
# KOI-245.01      39.792200
# KOI-245.02      21.302000
# KOI-245.03      13.367500
# KOI-246.01       5.398750
# KOI-246.02       9.605040
# KOI-261.01      16.238500
# KOI-283.01      16.092000
# KOI-283.02      25.516900
# KOI-292.01       2.586640
# KOI-299.01       1.541680
# KOI-305.01       4.603580
# KOI-321.01       2.426290
# KOI-321.02       4.623320
# KOI-41.01       12.815900
# KOI-41.02        6.887050
# KOI-41.03       35.333100
# KOI-69.01        4.726740
# KOI-82.01       16.145700
# KOI-82.02       10.311700
# KOI-82.03       27.453600
# KOI-82.04        7.071420
# KOI-82.05        5.286960
# KOI-94 b         3.743208
# Kepler-10 b      0.837495
# Kepler-11 b     10.303900
# Kepler-11 c     13.024100
# Kepler-11 d     22.684500
# Kepler-11 f     46.688800
# Kepler-18 b      3.504725
# Kepler-20 b      3.696122
# Kepler-20 c     10.854092
# Kepler-20 d     77.611840
# Kepler-30 b     29.334000
# Kepler-36 b     13.839890
# Kepler-36 c     16.238550
# Kepler-68 b      5.398763
# Kepler-68 c      9.605085
# Kepler-78 b      0.354167
# Name: per, Length: 60, dtype: float64

# %%
pearsonr(

# %%
# test polynomial fitting
# %matplotlib osx
my_poly = lambda x: 14 - 8 * x + 2 * x**2.
x = arange(0,4.1,0.1)
y = my_poly(x)
noise = np.random.normal(0,3,len(y))
noisy_data = y + noise
out5 = np.polynomial.polynomial.polyfit(x,noisy_data, 2, rcond=None, full=True)
my_pars = out5[0]
fig = plt.figure();
ax = fig.add_subplot(111);
ax.errorbar(x, noisy_data, yerr=[1.]*len(x), fmt='o', markersize=5, 
             alpha =0.5, color='k', capsize=0, elinewidth=2); # black option
ax.plot(x,y,label=("y = %.1f + %.1f x + %.1f x^2" % (my_pars[0], my_pars[1], my_pars[2])))
for r in xrange(0,4):
    mask = (r < x) & (x < r+1)
    xbin,ybin,yerr = x[mask],noisy_data[mask],noise[mask]
    ax.scatter((np.average(xbin, weights = (1./yerr**2.))),(np.average(ybin, weights = 1./yerr**2.)), s=100)
ax.legend();
plt.show();

# %%
notnan = numpy.logical_not(numpy.isnan(sp.fe))
from scipy.stats.stats import pearsonr
pearsonr(sp[notnan].fe, m_resid[notnan])
# Out:
# (0.20884444643126363, 0.12242174767036991)

# %%
from scipy.stats import linregress

# %%
linregress(sp.r, sp.m)
# Out:
# (3.4235980980507015,
#  -1.1532429874735612,
#  0.61037757357296463,
#  2.2432399067671895e-07,
#  0.58338605196348781)

# %%
#calculate standard errors
ssxx = sum((sp.r - np.mean(sp.r))**2.)
ssyy = sum((sp.m - np.mean(sp.m))**2.)
n = len(sp)
s = np.sqrt(sum(m_resid**2./(n-2)))
sea = s*np.sqrt(1./n + np.mean(sp.r)**2./ssxx)
seb = s/np.sqrt(ssxx)
print "Standard errors:"
print "Intercept:", sea, "Slope:", seb
# Out:
# Standard errors:
# Intercept: 0.470801103969 Slope: 0.223893463529

# %%
print ssxx/n
# Out:
# 0.730282212177

# %%
print np.mean(sp.ur**2.)
# Out:
# 0.0186611517341

# %%
from scipy import stats

# %%
import scikits.statsmodels.api as sm

# %%
sm.add_constant(sp.r)
model = sm.WLS(sp.m,sp.r,1./sp.um**2.)
result = model.fit()
# Out:
# /Users/lweiss/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/scikits/statsmodels/tools/tools.py:256: FutureWarning: The default of `prepend` will be changed to True in the next release, use explicit prepend
#   "next release, use explicit prepend", FutureWarning)

# %%
result.params
# Out:
# array([ 2.71404175])

# %%
# plot histograms
fig, axes = plt.subplots(nrows=1, ncols=3)
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
sp['r'].hist(ax=axes[0], bins = arange(0,5,0.5));
axes[0].set_xlabel('Radius ($\mathrm{R_E}$)', fontsize=16); 
axes[0].set_ylabel('Number', fontsize=16)
majorLocator   = MultipleLocator(0.5)
axes[0].xaxis.set_major_locator(majorLocator);
sp['m'].hist(ax=axes[1], bins = arange(-10,20,2)); 
axes[1].set_xlabel('Mass ($\mathrm{M_E}$)', fontsize=16)
majorLocator   = MultipleLocator(4)
axes[1].xaxis.set_major_locator(majorLocator)
sp['rho'].hist(ax=axes[2], range=(-10,30), bins = arange(-10,30,2)); 
axes[2].set_xlabel('Density (g/cc)', fontsize=16)
majorLocator   = MultipleLocator(4)
axes[2].xaxis.set_major_locator(majorLocator)
fig.set_size_inches(12,6);
subplots_adjust(wspace=0.1)
subplots_adjust(hspace=0.5)
plt.savefig('histograms.png',dpi=100)

# %%
print const
# Out:
# <module 'astropy.constants' from '/Users/lweiss/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/astropy/constants/__init__.py'>

# %%
const.M_earth.to('g')
# Out:
# <Quantity 5.9742e+27 g>

# %%
leastsq(
