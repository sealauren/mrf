# %%
# %pylab inline
import pickle
import numpy as np
import scipy as sp
import pandas as pd
from astropy import constants as const
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['axes', 'xscale']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
df = pickle.load(open('exoplanets.pickle'))
medf = np.median(df.flux)
df_hot = df[df.flux > medf]
df_cold = df[df.flux <= medf]
sp = pickle.load(open('small_exoplanets.pickle'))
#sp = sp.ix[sp.index!='Kepler-78 b',:]
sp['evap'] = sp.flux * sp.age
#sp.um = np.maximum(sp.um,0.1*sp.m)
#sp.ur = np.maximum(sp.ur,0.05*sp.r)
#sp.urho = np.maximum(abs(sp.urho), (np.sqrt((sp.um/sp.m)**2. + (3*sp.ur/sp.r)**2.)*sp.rho))
sp_clean = sp[sp.urho < 6.5]
sp_1sig = sp[sp.m > sp.um]
sp_cold = sp[sp.flux <= np.median(sp.flux)]
sp_hot = sp[sp.flux > np.median(sp.flux)]
sp['ttv'] = [0]*len(sp)
sp.ix[['Kepler-11 b','Kepler-11 c','Kepler-11 d','Kepler-11 f','Kepler-30 b','Kepler-36 b','Kepler-36 c'],'ttv'] = 1
ttvs = sp.ix[['Kepler-11 b','Kepler-11 c','Kepler-11 d','Kepler-11 f','Kepler-30 b','Kepler-36 b','Kepler-36 c'],:]
len(sp)
# Out:
# 60

# %%
sp.ix[:,['per','m','um','r','ur','flux','firstref','orbref']]
# Out:
#                     per          m        um         r        ur         flux  \
# name
# 55 Cnc e       0.736546   8.379902  0.392415  1.990000  0.084000  2439.689702
# CoRoT-7 b      0.853585   7.420000  1.210000  1.580000  0.100000  1779.432902
# GJ 1214 b      1.580405   6.450000  0.910000  2.650000  0.090000    16.320107
# HD 97658 b     9.490900   7.862465  0.730025  2.339998  0.165000    48.105998
# KOI-104.01     2.508060  10.840000  1.400000  3.510000  0.150000   238.747262
# KOI-108.01    15.965400  14.110000  4.700000  3.370000  0.090000   133.152439
# KOI-116.01    13.570800  10.440000  3.200000  2.500000  0.320000    92.172287
# KOI-116.02    43.844500  11.170000  5.800000  2.560000  0.330000    19.298378
# KOI-116.03     6.164860   0.150000  2.800000  0.820000  0.110000   263.942913
# KOI-116.04    23.980200  -6.390000  7.000000  0.950000  0.130000    43.145671
# KOI-122.01    11.523100  13.000000  2.900000  3.420000  0.090000   179.308712
# KOI-123.01     6.481630   1.300000  5.400000  2.370000  0.070000   412.928788
# KOI-123.02    21.222700   2.220000  7.800000  2.520000  0.070000    84.928469
# KOI-1442.01    0.669310   0.060000  1.200000  1.070000  0.020000  3670.035258
# KOI-148.01     4.778000   3.940000  2.100000  1.880000  0.100000   182.732012
# KOI-148.02     9.673950  14.610000  2.300000  2.710000  0.140000    71.340757
# KOI-148.03    42.896100   7.930000  4.600000  2.040000  0.110000     9.793075
# KOI-153.01     8.925070  -4.600000  6.200000  2.190000  0.060000    36.374126
# KOI-153.02     4.754000   7.100000  3.300000  1.820000  0.050000    84.242097
# KOI-1612.01    2.465020   0.480000  3.200000  0.820000  0.030000  1403.574185
# KOI-1925.01   68.958400   2.690000  6.200000  1.190000  0.030000     6.164804
# KOI-244.02     6.238500   9.600000  4.200000  2.710000  0.050000   481.745896
# KOI-245.01    39.792200   1.870000  9.080000  1.940000  0.060000    10.214952
# KOI-245.02    21.302000   3.350000  4.000000  0.750000  0.030000    23.500284
# KOI-245.03    13.367500   2.780000  3.700000  0.320000  0.020000    43.742140
# KOI-246.01     5.398750   5.970000  1.700000  2.330000  0.020000   406.874845
# KOI-246.02     9.605040   2.180000  3.500000  1.000000  0.020000   188.735195
# KOI-261.01    16.238500   8.460000  3.400000  2.670000  0.220000    62.124801
# KOI-283.01    16.092000  16.130000  3.500000  2.410000  0.200000    63.055987
# KOI-283.02    25.516900   8.250000  5.900000  0.840000  0.070000    34.101159
# KOI-292.01     2.586640   3.510000  1.900000  1.480000  0.130000   736.444219
# KOI-299.01     1.541680   3.550000  1.600000  1.990000  0.220000  1535.674313
# KOI-305.01     4.603580   6.150000  1.300000  1.480000  0.080000    99.742864
# KOI-321.01     2.426290   6.350000  1.400000  1.430000  0.030000   739.622386
# KOI-321.02     4.623320   2.710000  1.800000  0.850000  0.030000   313.084610
# KOI-41.01     12.815900   0.850000  4.000000  2.200000  0.050000   189.649523
# KOI-41.02      6.887050   7.340000  3.200000  1.320000  0.040000   434.083142
# KOI-41.03     35.333100  -4.360000  4.100000  1.610000  0.050000    49.057820
# KOI-69.01      4.726740   2.590000  2.000000  1.500000  0.030000   274.895999
# KOI-82.01     16.145700   8.930000  2.000000  2.220000  0.070000    21.079097
# KOI-82.02     10.311700   3.800000  1.800000  1.180000  0.040000    38.325469
# KOI-82.03     27.453600   0.620000  3.300000  0.880000  0.030000    10.386330
# KOI-82.04      7.071420  -1.580000  2.000000  0.580000  0.020000    63.375149
# KOI-82.05      5.286960   0.410000  1.600000  0.470000  0.020000    93.394178
# KOI-94 b       3.743208  10.500000  4.600000  1.710000  0.160000  1193.265629
# Kepler-10 b    0.837495   4.600000  1.260000  1.460000  0.020000  3674.693973
# Kepler-11 b   10.303900   1.900000  1.200000  1.800000  0.040000   125.271106
# Kepler-11 c   13.024100   2.900000  2.200000  2.870000  0.050000    91.598692
# Kepler-11 d   22.684500   7.300000  1.100000  3.120000  0.060000    43.695654
# Kepler-11 f   46.688800   2.000000  1.200000  2.490000  0.050000    16.691612
# Kepler-18 b    3.504725   6.991965  3.495983  2.000018  0.099984   462.243737
# Kepler-20 b    3.696122   8.474453  2.122106  1.908295  0.164853   346.710610
# Kepler-20 c   10.854092  15.733766  3.314223  3.067259  0.254772    82.444687
# Kepler-20 d   77.611840   7.527963  7.218473  2.747545  0.234790     5.984927
# Kepler-30 b   29.334000  11.300605  1.400074  3.896522  0.199821    21.514893
# Kepler-36 b   13.839890   4.461478  0.300773  1.484674  0.034969   217.365219
# Kepler-36 c   16.238550   8.100828  0.531364  3.675716  0.053952   175.645876
# Kepler-68 b    5.398763   8.321392  2.305925  2.307940  0.074933   409.091742
# Kepler-68 c    9.605085   4.812379  3.057857  0.952149  0.039465   189.763836
# Kepler-78 b    0.354167   1.690000  0.410000  1.200000  0.090000  3093.471095
#
#                               firstref                    orbref
# name
# 55 Cnc e                 McArthur 2004  Endl 2012, Dragomir 2013
# CoRoT-7 b     Queloz 2009 ; Leger 2009               Hatzes 2012
# GJ 1214 b             Charbonneau 2009               Carter 2011
# HD 97658 b                 Howard 2011             Dragomir 2013
# KOI-104.01                Borucki 2011                Marcy 2013
# KOI-108.01                Borucki 2011                Marcy 2013
# KOI-116.01                Borucki 2011                Marcy 2013
# KOI-116.02                Borucki 2011                Marcy 2013
# KOI-116.03                Borucki 2011                Marcy 2013
# KOI-116.04                Borucki 2011                Marcy 2013
# KOI-122.01                Borucki 2011                Marcy 2013
# KOI-123.01                Borucki 2011                Marcy 2013
# KOI-123.02                Borucki 2011                Marcy 2013
# KOI-1442.01               Borucki 2011                Marcy 2013
# KOI-148.01                Borucki 2011                Marcy 2013
# KOI-148.02                Borucki 2011                Marcy 2013
# KOI-148.03                Borucki 2011                Marcy 2013
# KOI-153.01                Borucki 2011                Marcy 2013
# KOI-153.02                Borucki 2011                Marcy 2013
# KOI-1612.01               Borucki 2011                Marcy 2013
# KOI-1925.01               Borucki 2011                Marcy 2013
# KOI-244.02                Borucki 2011                Marcy 2013
# KOI-245.01                Borucki 2011                Marcy 2013
# KOI-245.02                Borucki 2011                Marcy 2013
# KOI-245.03                Borucki 2011                Marcy 2013
# KOI-246.01                Borucki 2011                Marcy 2013
# KOI-246.02                Borucki 2011                Marcy 2013
# KOI-261.01                Borucki 2011                Marcy 2013
# KOI-283.01                Borucki 2011                Marcy 2013
# KOI-283.02                Borucki 2011                Marcy 2013
# KOI-292.01                Borucki 2011                Marcy 2013
# KOI-299.01                Borucki 2011                Marcy 2013
# KOI-305.01                Borucki 2011                Marcy 2013
# KOI-321.01                Borucki 2011                Marcy 2013
# KOI-321.02                Borucki 2011                Marcy 2013
# KOI-41.01                 Borucki 2011                Marcy 2013
# KOI-41.02                 Borucki 2011                Marcy 2013
# KOI-41.03                 Borucki 2011                Marcy 2013
# KOI-69.01                 Borucki 2011                Marcy 2013
# KOI-82.01                 Borucki 2011                Marcy 2013
# KOI-82.02                 Borucki 2011                Marcy 2013
# KOI-82.03                 Borucki 2011                Marcy 2013
# KOI-82.04                 Borucki 2011                Marcy 2013
# KOI-82.05                 Borucki 2011                Marcy 2013
# KOI-94 b                  Borucki 2011                Weiss 2013
# Kepler-10 b               Batalha 2011       Fogtmann-Shulz 2013
# Kepler-11 b              Lissauer 2011             Lissauer 2013
# Kepler-11 c              Lissauer 2011             Lissauer 2013
# Kepler-11 d              Lissauer 2011             Lissauer 2013
# Kepler-11 f              Lissauer 2011             Lissauer 2013
# Kepler-18 b               Borucki 2011              Cochran 2011
# Kepler-20 b               Borucki 2011              Gautier 2012
# Kepler-20 c               Borucki 2011              Gautier 2012
# Kepler-20 d               Borucki 2011              Gautier 2012
# Kepler-30 b               Borucki 2011        Sanchis-Ojeda 2012
# Kepler-36 b               Borucki 2011               Carter 2012
# Kepler-36 c                Carter 2012               Carter 2012
# Kepler-68 b               Borucki 2011            Gilliland 2013
# Kepler-68 c               Batalha 2013            Gilliland 2013
# Kepler-78 b         Sanchis-Ojeda 2013      Sanchis-Ojeda (2013)

# %%
ttvs.ix[:,['rho','urho']]
# Out:
#               rho   urho
# Kepler-11 b  1.72  1.080
# Kepler-11 c  0.66  0.500
# Kepler-11 d  1.28  0.210
# Kepler-11 f  0.69  0.300
# Kepler-30 b  1.02  0.130
# Kepler-36 b  7.46  0.665
# Kepler-36 c  0.89  0.060

# %%
mearth = 5.9721986E27 #grams
rearth = 6.3675E8 #centimeters
msun = 1.988435E33 #grams
rsun = 6.955E10 #centimeters
cmperau=1.496E13
lsun = 3.846E33 #ergs per second
tsun = 5780 #kelvins
ss_names = {"name" : ['Me','V','E','Ma','J','S','U','N']}
ss = pd.DataFrame(ss_names) 
ss['m'] = [0.0553, 0.815, 1.00, 0.107, 317.83, 95.159, 14.536, 17.147]
ss['um'] = ss.m*0.10
ss['r'] = [0.383,0.950,1.0, 0.532, 10.973, 9.140, 3.981, 3.865]
ss['ur'] = ss.r*0.05
ss['a'] = [0.387, 0.723 , 1.0, 1.524, 5.204, 9.582, 19.201, 30.047]
ss['rho'] = (ss.m * mearth)/(4./3 * np.pi * (ss.r * rearth)**3.)
ss['urho'] = np.sqrt((ss.um/ss.m)**2. + (3*ss.ur/ss.r)**2.)*ss.rho
ss['flux'] = 1./ss.a**2
ss['per'] = 365.25 * pow(ss.a, 3./2)
ss['fe'] = [0.0]*8
ss['age'] = [5.0]*8
ss = ss.set_index('name')
ss.head()
# Out:
#              m        um       r       ur      a       rho      urho  \
# name
# Me      0.0553   0.00553   0.383  0.01915  0.387  5.435851  0.979962
# V       0.8150   0.08150   0.950  0.04750  0.723  5.249592  0.946384
# E       1.0000   0.10000   1.000  0.05000  1.000  5.522539  0.995590
# Ma      0.1070   0.01070   0.532  0.02660  1.524  3.924530  0.707505
# J     317.8300  31.78300  10.973  0.54865  5.204  1.328488  0.239497
#
#           flux          per  fe  age
# name
# Me    6.676949    87.933968   0    5
# V     1.913037   224.542043   0    5
# E     1.000000   365.250000   0    5
# Ma    0.430556   687.175513   0    5
# J     0.036925  4336.068720   0    5

# %%
sp_rocky = sp[sp.r < 1.5].append(ss[ss.r < 1.5])
sp_rocky.ix[:,['r','ur','m','um','rho','urho']]
# Out:
#                      r        ur         m        um         rho        urho
# name
# KOI-116.03    0.820000  0.110000  0.150000  2.800000    1.260000   26.260000
# KOI-116.04    0.950000  0.130000 -6.390000  7.000000  -41.000000   39.750000
# KOI-1442.01   1.070000  0.020000  0.060000  1.200000    0.290000    5.700000
# KOI-1612.01   0.820000  0.030000  0.480000  3.200000    4.420000   29.820000
# KOI-1925.01   1.190000  0.030000  2.690000  6.200000    8.880000   20.600000
# KOI-245.02    0.750000  0.030000  3.350000  4.000000   44.330000   53.600000
# KOI-245.03    0.320000  0.020000  2.780000  3.700000  548.800000  700.000000
# KOI-246.02    1.000000  0.020000  2.180000  3.500000   10.770000   17.290000
# KOI-283.02    0.840000  0.070000  8.250000  5.900000   77.700000   55.000000
# KOI-292.01    1.480000  0.130000  3.510000  1.900000    5.440000    3.480000
# KOI-305.01    1.480000  0.080000  6.150000  1.300000   10.900000    2.820000
# KOI-321.01    1.430000  0.030000  6.350000  1.400000   11.820000    2.700000
# KOI-321.02    0.850000  0.030000  2.710000  1.800000   24.390000   16.130000
# KOI-41.02     1.320000  0.040000  7.340000  3.200000   14.250000    6.330000
# KOI-82.02     1.180000  0.040000  3.800000  1.800000   13.270000    6.460000
# KOI-82.03     0.880000  0.030000  0.620000  3.300000    4.920000   24.500000
# KOI-82.04     0.580000  0.020000 -1.580000  2.000000  -44.240000   56.700000
# KOI-82.05     0.470000  0.020000  0.410000  1.600000   23.290000   94.930000
# Kepler-10 b   1.460000  0.020000  4.600000  1.260000    8.150000    2.260000
# Kepler-36 b   1.484674  0.034969  4.461478  0.300773    7.460000    0.665000
# Kepler-68 c   0.952149  0.039465  4.812379  3.057857   28.000000   18.000000
# Kepler-78 b   1.200000  0.090000  1.690000  0.410000    5.300000    1.800000
# Me            0.383000  0.019150  0.055300  0.005530    5.435851    0.979962
# V             0.950000  0.047500  0.815000  0.081500    5.249592    0.946384
# E             1.000000  0.050000  1.000000  0.100000    5.522539    0.995590
# Ma            0.532000  0.026600  0.107000  0.010700    3.924530    0.707505

# %%
from scipy.stats import pearsonr
print "Pearson R, Null prob. on M-R correlation:", pearsonr(sp.r, sp.m)
# Out:
# Pearson R, Null prob. on M-R correlation: (0.60734171411505899, 2.6721269992727383e-07)

# %%
# plot whole population in r vs. m, d vs. m
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1, xscale="log", yscale="log") 
ax2 = fig.add_subplot(1,2,2, xscale="log", yscale="log") 
ax1.errorbar(df_hot.m, df_hot.r, xerr=df_hot.um, yerr=df_hot.ur, 
             fmt='o', markersize=5, 
             alpha=0.5, color='r', label='$F > $ %i $F_E$'%medf, 
             capsize=0);
ax1.errorbar(df_cold.m, df_cold.r, xerr=df_cold.um, yerr=df_cold.ur, 
             fmt='o', markersize=5, 
             alpha =0.5, color='b', label='$F < $ %i $F_E$'%medf, 
             capsize=0);
for x in zip(ss.m,ss.r,ss.index):
    ax1.text(x[0], x[1], x[2], fontsize=12, family='monospace', color='k')
ax2.errorbar(df_hot.m, df_hot.rho, xerr=df_hot.um, yerr=df_hot.urho, 
             fmt='o', markersize=5, 
             alpha=0.5, color='r', label='$F > $ %i $F_E$'%medf, 
             capsize=0);
ax2.errorbar(df_cold.m, df_cold.rho, xerr=df_cold.um, yerr=df_cold.urho, 
             fmt='o', markersize=5, 
             alpha=0.5, color='b', label='$F < $ %i $F_E$'%medf,
             capsize=0);
for x in zip(ss.m,ss.rho,ss.index):
    ax2.text(x[0], x[1], x[2], fontsize=12, family='monospace', color='k')
ax1.set_xlabel('Planet Mass ($\mathrm{M_E}$)', fontsize=16)
ax2.set_xlabel('Planet Mass ($\mathrm{M_E}$)', fontsize=16)
ax1.set_ylabel('Planet Radius ($\mathrm{R_E}$)',fontsize=16)
ax2.set_ylabel('Planet Density (g/cc)',fontsize=16)
ax1.legend(loc='lower right');
ax2.legend(loc='upper right');
fig.set_size_inches(12,6)
plt.savefig('mrf.eps')

# %%
# plot histograms
fig, axes = plt.subplots(nrows=1, ncols=3)
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
sp['r'].hist(ax=axes[0], bins = arange(0,5,0.5));
axes[0].set_xlabel('Radius ($\mathrm{R_E}$)', fontsize=16); 
axes[0].set_ylabel('Number', fontsize=16)
majorLocator   = MultipleLocator(0.5)
axes[0].xaxis.set_major_locator(majorLocator);
sp['m'].hist(ax=axes[1], bins = arange(-10,20,2)); 
axes[1].set_xlabel('Mass ($\mathrm{M_E}$)', fontsize=16)
majorLocator   = MultipleLocator(4)
axes[1].xaxis.set_major_locator(majorLocator)
sp['rho'].hist(ax=axes[2], range=(-10,30), bins = arange(-10,30,2)); 
axes[2].set_xlabel('Density (g/cc)', fontsize=16)
majorLocator   = MultipleLocator(4)
axes[2].xaxis.set_major_locator(majorLocator)
fig.set_size_inches(12,6);
subplots_adjust(wspace=0.1)
subplots_adjust(hspace=0.5)
plt.savefig('histograms.png',dpi=100)
plt.savefig('histograms.eps', format='eps', dpi=300)

# %%
# numerical weighted linear fit
fitfunc = lambda p, x: p[0] + p[1] * x
errfunc = lambda p, x, y, err: (y - fitfunc(p, x)) / err  
from scipy.optimize import leastsq
out = leastsq(errfunc,  [0.2,2.5], args=(sp.r, sp.m, sp.um),full_output=1)
best_pars = out[0]
print "Best parameters:", best_pars
print "Covariance:", out[1]
print "Chi^2:", (errfunc(out[0],sp.r,sp.m,sp.um)**2.).sum()/(len(sp.m) - len(out[0]))
print "RMS:", np.sqrt(np.mean((sp.m - fitfunc(best_pars,sp.r))**2.))
rarr = linspace(0.0, 4.0, 101)
marr = fitfunc(best_pars,rarr)
darr = (marr*mearth)/(4./3.*pi*(rarr*rearth)**3)
darr[darr < 0] = 100
# Out:
# Best parameters: [ 0.39207151  2.63230159]
# Covariance: [[ 0.1602742  -0.07158518]
#  [-0.07158518  0.03752171]]
# Chi^2: 3.34125031379
# RMS: 3.86830666925

# %%
#calculate standard errors
ssxx = sum((sp.r - np.mean(sp.r))**2.)
ssyy = sum((sp.m - np.mean(sp.m))**2.)
n = len(sp)
s = np.sqrt(sum((sp.m - fitfunc(best_pars,sp.r))**2./(n-2)))
sea = s*np.sqrt(1./n + np.mean(sp.r)**2./ssxx)
seb = s/np.sqrt(ssxx)
print "Standard errors:"
print "Intercept:", sea, "Slope:", seb
# Out:
# Standard errors:
# Intercept: 1.24972257598 Slope: 0.594968564885

# %%
# this is an *analytical* weighted polynomial fit to density vs. radius -- the best!
out4 = np.polynomial.polynomial.polyfit(sp.r, sp.rho, 2, rcond=None, full=True, w=1./sp.urho**2.)
best_q = out4[0]
poly2 = lambda p, x: p[0] + p[1] * x + p[2] * x**2.
darr3 = best_q[0] + best_q[1] * rarr + best_q[2] * rarr**2.# + best_q[3] * rarr**3.
rho_pred = best_q[0] + best_q[1] * sp.r + best_q[2] * sp.r**2.# + best_q[3] * sp.r**3.
print "Best parameters:", out4[0]
print "Covariance:", out4[1]
print "Chi^2:", (((sp.rho - rho_pred)/sp.urho)**2.).sum()/(len(sp.rho) - len(out4[0]))
print "RMS:", np.sqrt(np.mean((sp.rho - poly2(best_q,sp.r))**2.))
print "RMS:", np.sqrt(np.mean((sp[sp.r > 1.5].rho - poly2(best_q,sp[sp.r > 1.5].r))**2.))
# Out:
# Best parameters: [ 11.26368717  -5.85820352   0.82629907]
# Covariance: [array([ 428.45968721]), 3, array([ 1.73176232,  0.03155406,  0.00190087]), 1.3322676295501878e-14]
# Chi^2: 2.54037676504
# RMS: 71.1691144326
# RMS: 2.84613384255

# %%
powerlaw = lambda p, x: p[0] * x**(p[1])
powerlaw2 = lambda p, x: pow(x,p[0])
errfunc_plaw = lambda p, x, y, err : (y - powerlaw(p, x))/err
errfunc_plaw2 = lambda p, x, y, err : (y - powerlaw2(p, x))/err

mass_plaw = leastsq(errfunc_plaw,  [3.,1.], 
              args=(sp.r, sp.m, sp.um),full_output=1)
mpars = mass_plaw[0]
mplaw = mpars[0] * pow(rarr,mpars[1])
print "Mass Power Law Solution:"
print "Best parameters:", mpars
print "Covariance:", mass_plaw[1]
print "Chi^2:", (errfunc_plaw(mpars,sp.r,sp.m,sp.um)**2.).sum()/(len(sp.m) - len(mpars))
print "RMS:", np.sqrt(np.mean((sp.m - powerlaw(mpars,sp.r))**2))

density_plaw = leastsq(errfunc_plaw,  [8.,-1.], 
                       args=(sp.r, sp.rho, sp.urho),full_output=1)
dpars = density_plaw[0]
dplaw = dpars[0] * pow(rarr,dpars[1])
#print "********************************"
#print "Density Power Law Solution:"
#print "Best parameters:", dpars
#print "Covariance:", density_plaw[1]
#print "Chi^2:", (errfunc_plaw(dpars,sp.r,sp.rho,sp.urho)**2.).sum()/(len(sp.m) - len(dpars))
#print "RMS:", np.sqrt(np.mean((sp.rho - powerlaw(dpars,sp.r))**2))
#print "RMS:", np.sqrt(np.mean((sp[sp.r > 1.5].rho - powerlaw(dpars,sp[sp.r > 1.5].r))**2))
# Out:
# Mass Power Law Solution:
# Best parameters: [ 3.15412471  0.86693874]
# Covariance: [[ 0.03906039 -0.01206404]
#  [-0.01206404  0.00453698]]
# Chi^2: 3.28140691155
# RMS: 3.89075228084

# %%
# Fits to the rocky planets
rocky_plaw_no_ss = leastsq(errfunc_plaw,  [1.,3.], 
              args=(sp[sp.r < 1.5].r, sp[sp.r < 1.5].m, sp[sp.r < 1.5].um),full_output=1)
rocky_plaw = leastsq(errfunc_plaw,  [1.,3.], 
              args=(sp_rocky.r, sp_rocky.m, sp_rocky.um),full_output=1)
rocky_pars = rocky_plaw[0]
rocky_pars_no_ss = rocky_plaw_no_ss[0]
rocky_r = arange(0.01,1.5,0.01)
rockplaw = powerlaw(rocky_pars,rocky_r)
print "********************************"
print "Rocky Mass Power Law Solution:"
print "Best parameters without SS:", rocky_pars_no_ss
print "Best parameters:", rocky_pars
print "Covariance:", rocky_plaw[1]
print "Chi^2 without SS:", (errfunc_plaw(rocky_pars_no_ss,
                              sp[sp.r < 1.5].r,sp[sp.r < 1.5].m,
                              sp[sp.r < 1.5].um)**2.).sum()/(len(sp[sp.r < 1.5].m) - len(mpars))
print "Chi^2:", (errfunc_plaw(rocky_pars,
                              sp_rocky.r,sp_rocky.m,
                              sp_rocky.um)**2.).sum()/(len(sp_rocky.m) - len(rocky_pars))
print "Chi^2 to mr plaw without SS:", (errfunc_plaw(mpars,
                              sp[sp.r < 1.5].r,sp[sp.r < 1.5].m,
                              sp[sp.r < 1.5].um)**2.).sum()/(len(sp[sp.r < 1.5].m) - len(mpars))
print "Chi^2 to mr plaw:", (errfunc_plaw(mpars,
                              sp_rocky.r,sp_rocky.m,
                              sp_rocky.um)**2.).sum()/(len(sp_rocky.m) - len(mpars))
print "RMS:", np.sqrt(np.mean((sp_rocky.m - powerlaw(rocky_pars,sp_rocky.r))**2))
print "RMS without SS:", np.sqrt(np.mean((sp[sp.r < 1.5].m - powerlaw(mpars,sp[sp.r < 1.5].r))**2))

rocky_dens = leastsq(errfunc_plaw,  [10.,-2.], 
              args=(sp_rocky.r, sp_rocky.rho, sp_rocky.urho),full_output=1)
rocky_d = rocky_dens[0]
rockdlaw = rocky_d[0] * pow(rocky_r,rocky_d[1])
print "********************************"
print "Rocky Density Power Law Solution:"
print "Best parameters:", rocky_d
print "Covariance:", rocky_dens[1]
print "Chi^2:", (errfunc_plaw(rocky_d,
                              sp_rocky.r,sp_rocky.rho,
                              sp_rocky.urho)**2.).sum()/(len(sp_rocky.rho) - len(rocky_d))
print "RMS:", np.sqrt(np.mean((sp_rocky[sp_rocky.rho < 100].rho - powerlaw(rocky_d,sp_rocky[sp_rocky.rho < 100].r))**2))

polytrope = lambda n, x: 4/3.*pi*(x/3.90)**3.*10.55*(1. + (1. - 3./5.*n)*pow((2./3.*pi*(x/3.90)**2.),n))
#polytrope = lambda n, x: 1. + (1. - 3./5.*n)*pow((2./3.*pi*x**2.),n)
#polytrope = lambda k, x: pow(10,k[0]) * pow(x,1/3.)*k[2]*pow(10,k[1]*x)
errfunc_ptrope = lambda n, x, y, err : (y - polytrope(n, x))/err
m_polytrope = leastsq(errfunc_ptrope,  [9/3.], 
              args=(sp_rocky.r, sp_rocky.m, sp_rocky.um),full_output=1)
ptrope = m_polytrope[0]
print "********************************"
print "Rocky Mass Polytrope Solution:"
print "Best parameter:", ptrope
print "Covariance:", m_polytrope[1]
print "Chi^2:", (errfunc_ptrope(ptrope,
                              sp_rocky.r,sp_rocky.m,
                              sp_rocky.um)**2.).sum()/(len(sp_rocky.m) - len(ptrope))
m_ptrope = polytrope(ptrope, rocky_r)
# Out:
# ********************************
# Rocky Mass Power Law Solution:
# Best parameters without SS: [ 0.94155531  4.0199448 ]
# Best parameters: [ 1.08437388  3.44634648]
# Covariance: [[ 0.00175322  0.00051823]
#  [ 0.00051823  0.0074453 ]]
# Chi^2 without SS: 0.882802840916
# Chi^2: 1.32414992188
# Chi^2 to mr plaw without SS: 2.30136060426
# Chi^2 to mr plaw: 3503.33482579
# RMS: 2.70471648212
# RMS without SS: 2.95273793062
# ********************************
# Rocky Density Power Law Solution:
# Best parameters: [ 6.12278513  0.49397137]
# Covariance: [[ 0.12627285 -0.00828115]
#  [-0.00828115  0.01891567]]
# Chi^2: 0.881010851039
# RMS: 22.5740452078
# ********************************
# Rocky Mass Polytrope Solution:
# Best parameter: [ 98.6838495]
# Covariance: None
# Chi^2: 3.93088038776

# %%
# find uncertainties in plaw with bootstrap
def draw_data(x,ux):
    x_pbs = np.array([x[i] + random.normal(ux[i]) for i in np.arange(len(x))])
    #d_pbs = [sp.rho[i] + random.normal(sp.urho[i]) for i in np.arange(len(sp))]
    return x_pbs

# %%
# do 1000 draws and store the power law coefficients
mr_plaw_pbs = []
dr_plaw_pbs = []
dr_poly_pbs = []
mr_rocky_pbs = []
dr_rocky_pbs = []
#ums = [sp.um[i] for i in np.arange(len(sp))]
#uds = [sp.urho[i] for i in np.arange(len(sp))]
for i in xrange(0,1000):
#if "x"=="x":
    # draw a mass and density
    ms = draw_data(sp.m, sp.um)
    ds = draw_data(sp.rho, sp.urho)
    ms_rocky = draw_data(sp_rocky.m, sp_rocky.um)
    ds_rocky = draw_data(sp_rocky.rho, sp_rocky.urho)
#    plt.errorbar(rs,ms,yerr=ums,fmt='o')
    # calculate best fits for these m's and d's
    mr_plaw_pbs.append(leastsq(errfunc_plaw,  [3.,1.], args=(sp.r,ms,sp.um))[0])
    dr_plaw_pbs.append(leastsq(errfunc_plaw,  [10.,-2.], args=(sp.r,ds,sp.urho))[0])
    dr_poly_pbs.append(np.polynomial.polynomial.polyfit(sp.r, ds, 2, rcond=None, w=1./sp.urho**2.))
    mr_rocky_pbs.append(leastsq(errfunc_plaw,  [1.,3.], args=(sp_rocky.r, ms_rocky, sp_rocky.um))[0])
    dr_rocky_pbs.append(leastsq(errfunc_plaw,  [10.,-2.], args=(sp_rocky.r, ds_rocky, sp_rocky.urho))[0])

# %%
print "mr power law coefficients:"
print "mean:", np.mean(mr_plaw_pbs,axis=0), "\t","\t","std:",np.std(mr_plaw_pbs,axis=0)
print "****************************************************************"
#print "dr power law coefficients:"
#print "mean:", np.mean(dr_plaw_pbs,axis=0),"\t", "\t","std:",np.std(dr_plaw_pbs,axis=0) 
#print "****************************************************************"
print "dr polynomial coefficients:"
print "mean:", np.mean(dr_poly_pbs, axis=0),"\t", "std:",np.std(dr_poly_pbs, axis=0)
print "****************************************************************"
print "mr rocky power law coefficients:"
print "mean:", np.mean(mr_rocky_pbs, axis=0),"\t", "\t","std:", np.std(mr_rocky_pbs,axis=0)
print "****************************************************************"
print "dr rocky power law coefficients:"
print "mean:", np.mean(dr_rocky_pbs,axis=0),"\t","\t", "std:", np.std(dr_rocky_pbs,axis=0)
# Out:
# mr power law coefficients:
# mean: [ 3.85157453  0.80144117] 		std: [ 0.45965949  0.11190219]
# ****************************************************************
# dr polynomial coefficients:
# mean: [ 16.34654107  -8.71417874   1.22784763] 	std: [ 36.21182214  23.38118461   3.63244772]
# ****************************************************************
# mr rocky power law coefficients:
# mean: [ 0.77830462  0.49041697] 		std: [ 1.11826797  8.50439795]
# ****************************************************************
# dr rocky power law coefficients:
# mean: [ 7.19667279  0.46175046] 		std: [ 0.44712236  0.16212875]

# %%
# calculated predict masses, densities
#rpred = (sp.m - best_pars[0])/best_pars[1]
mpred = powerlaw(mpars,sp.r)
#dpred = mpred*mearth/(4./3.*(rpred*rearth)**3.)
#r_resid = sp.r - rpred
m_resid = sp.m - mpred
#d_resid = sp.rho - dpred
rms = np.sqrt(np.mean(m_resid**2))
print rms
sp['m_resid'] = m_resid
# Out:
# 3.89075228084

# %%
# bin mass, radius, density
rwm, rwd, urw, mw, umw, rhow, urhow = [], [], [], [], [], [], []
for r in arange(0,4.,0.5):
    rbin = sp.loc[r <= sp.r].loc[sp.r < r+0.5]
    rwm.append(np.average(rbin['r'], weights = (1./rbin.um**2.)))
    rwd.append(np.average(rbin['r'], weights = (1./rbin.urho**2.)))
    mw.append(np.average(rbin['m'], weights = 1./rbin.um**2.))
    rhow.append(np.average(rbin['rho'], weights = 1./rbin.urho**2.))
    urw.append(std(rbin.r)/sqrt(len(rbin)))
    umw.append(std(rbin.m)/sqrt(len(rbin)))
    urhow.append(std(rbin.rho)/sqrt(len(rbin)))
means = pd.DataFrame({'r_m':rwm, 'r_d':rwd, 'ur':urw, 'm':mw, 'um':umw, 'rho':rhow, 'urho':urhow})

# %%
# Calculate Earth composition from Seager 2007
# this is good for Ms < 4
m1, 6.41; r1 = 3.19
k1 = -0.20945; k2 = 0.0804; k3 = 0.394
m_phys = np.logspace(-3, 1, num=50)
ms = m_phys/m1; rs = r_phys/r1
logrs = k1 + 1/3. * np.log10(ms) - k2 * ms**k3
rs = pow(10.,logrs)
print max(ms), max(rs*r1)
m_seager = ms*m1; r_seager = rs*r1
d_seager = m_seager/(4/3.*pi*r_seager**3.)*mearth/rearth**3.
print zip(r_seager,d_seager)
# Out:
# 1.5600624025 1.83199330367
# [(0.10540105596661349, 4.7163267477002666), (0.11216577528030169, 4.722699760213855), (0.11936052937252337, 4.7295722963700237), (0.12701205070157873, 4.7369843082959742), (0.13514864445033922, 4.7449790713754405), (0.14380026774032842, 4.7536034809869969), (0.15299861075523999, 4.762908378901848), (0.16277717944541953, 4.7729489127803228), (0.1731713794017164, 4.7837849326724466), (0.18421860039054533, 4.7954814289664638), (0.19595830093015726, 4.8081090168531668), (0.20843209215898037, 4.8217444730969454), (0.22168382009819526, 4.8364713317457477), (0.2357596452399601, 4.8523805463924603), (0.25070811819718508, 4.869571227743922), (0.26658024992743473, 4.8881514665941355), (0.28342957478921083, 4.9082392538688024), (0.30131220439998158, 4.9299635112559637), (0.32028686993813793, 4.9534652481153634), (0.34041495016159684, 4.9788988629318975), (0.36176048199986899, 5.0064336106264173), (0.38439015010978062, 5.0362552606571995), (0.4083732512633827, 5.0685679751556485), (0.4337816288556488, 5.1035964414873343), (0.46068957217538359, 5.1415882997930744), (0.48917367437179854, 5.1828169134676934), (0.51931264226868135, 5.227584539451251), (0.55118705032626536, 5.2762259659832447), (0.58487903012762743, 5.3291126985328825), (0.62047188577361856, 5.3866577905065922), (0.65804962451263227, 5.4493214347247125), (0.69769639081726653, 5.5176174554092272), (0.73949579096204954, 5.5921208696207652), (0.78353009397376794, 5.6734767231104364), (0.82987929364464341, 5.7624104501853015), (0.87862001515399779, 5.8597400627047982), (0.92982424878238945, 5.9663905426770532), (0.98355789228329982, 6.0834108999330825), (1.0398790827770568, 6.2119944660146889), (1.0988362986445348, 6.3535031342617039), (1.1604662119411238, 6.5094964327542417), (1.2247912724668337, 6.6817665426904096), (1.2918170059874148, 6.8723806652052239), (1.3615290114073515, 7.0837325150038373), (1.4338896451869361, 7.3186052070713625), (1.5088343862476847, 7.5802484405765531), (1.5862678813362023, 7.8724737230774018), (1.6660596796656215, 8.1997724886685344), (1.748039677007077, 8.5674634433385659), (1.8319933036658582, 8.9818774556988377)]

# %%
# plot mass, density vs. radius
#%matplotlib osx
# %pylab inline
fig = plt.figure()
pylab.sharex=True
ax1 = fig.add_subplot(1,2,1)
ax1.errorbar(sp.r, sp.m, xerr=sp.ur, yerr=sp.um, fmt='o', markersize=5, 
             alpha =0.3, color='gray', capsize=0, elinewidth=2); # black option
ax1.plot(rarr, mplaw, '--k', linewidth=4, label=("M = %.2f * R^ %.2f"% (mpars[0], mpars[1])))
ax1.plot(rarr, marr, '--r', linewidth=4, label=("M = %.2f + %.2f R" % (best_pars[0], best_pars[1])))
ax1.plot(rocky_r, rockplaw, '--c', linewidth=4, label=("M = %.2f R^ %.2f"% (rocky_pars[0], rocky_pars[1])))
#ax1.plot(rocky_r, m_ptrope, '--g', linewidth=4, label=("polytrope n= %.1f"% ptrope))
ax1.errorbar(means.r_m,means.m, xerr=means.ur, yerr=means.um, 
             markersize=10, marker='s',fmt='o', capsize=0, elinewidth=4, alpha = 0.8)
ax1.errorbar(ttvs.r, ttvs.m, xerr=ttvs.ur, yerr=ttvs.um, fmt='o',capsize=0, elinewidth=2, alpha=0.5, color='orange', label=('TTVs'))
ax1.set_xlabel('Planet Radius ($\mathrm{R_E}$)',fontsize=24)
ax1.set_ylabel('Planet Mass ($\mathrm{M_E})$',fontsize=24)
for x in zip(ss.r,ss.m,ss.index):
    if (x[1] < 20) and (x[1] > -3) and (x[0] < 4.):
        ax1.text(x[0], x[1], x[2], fontsize=12, family='monospace', color='m')
ax1.legend(loc='upper left');
pyplot.axis([0.0,4.1,-3,20])

ax2 = fig.add_subplot(1,2,2)
ax2.plot(r_seager,d_seager, color='g', alpha = 0.5, linewidth=4, label=('Earth Composition (Seager 2007)'))
ax2.errorbar(sp.r, sp.rho, xerr=sp.ur, yerr=sp.urho, fmt='o', markersize=5, 
             alpha=0.3, color='gray',capsize=0, elinewidth=2);
ax2.plot(rarr, darr3, '--k', linewidth=4, label=("Rho = %.2f + %.2f R + %.2f R^2" % (best_q[0], best_q[1], best_q[2])))
#ax2.plot(rarr, dplaw, '--r', linewidth=4, label=("Rho = %.2f * R^ %.2f"% (dpars[0], dpars[1])))
#ax2.plot(rocky_r, rockdlaw, '--c', linewidth=4, label=("Rho = %.2f * R^ %.2f"% (rocky_d[0], rocky_d[1])))
ax2.set_xlabel('Planet Radius ($\mathrm{R_E}$)',fontsize=24)
ax2.set_ylabel('Planet Density ($\mathrm{g/cm^{3}}$)',fontsize=24)
ax2.errorbar(means.r_d,means.rho, xerr=means.ur, yerr=means.urho, 
             markersize=10, marker='s', fmt='o', capsize=0, elinewidth=4, alpha=0.8)
ax2.errorbar(ttvs.r, ttvs.rho, xerr=ttvs.ur, yerr=ttvs.urho, fmt='o',capsize=0, elinewidth=2, alpha=0.5, color='orange',label=('TTVs'))
#ax2.errorbar(sp.ix['Kepler-78 b','r'], sp.ix['Kepler-78 b','rho'], 
#             xerr=sp.ix['Kepler-78 b','ur'], yerr=sp.ix['Kepler-78 b','urho'], fmt='o',capsize=0, elinewidth=4, 
#             alpha=0.5, color='r')
for x in zip(ss.r,ss.rho,ss.index):
    if (x[1] < 30) and (x[1] > -1) and (x[0] < 4.):
        ax2.text(x[0], x[1], x[2], fontsize=12, family='monospace', color='m')
pyplot.axis([0.,4.0,-5,40])
ax2.legend();

fig.set_size_inches(12,6)
subplots_adjust(wspace=0.3)
subplots_adjust(hspace=0.2)
plt.savefig('mr_small.png', dpi=100)
plt.savefig('mr_small.eps', format='eps', dpi=300)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['xscale']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
ordered_d = sp.sort('r')
print ordered_d.ix[:,['r','rho','urho']]
# Out:
#                      r         rho        urho
# name
# KOI-245.03    0.320000  548.800000  700.000000
# KOI-82.05     0.470000   23.290000   94.930000
# KOI-82.04     0.580000  -44.240000   56.700000
# KOI-245.02    0.750000   44.330000   53.600000
# KOI-116.03    0.820000    1.260000   26.260000
# KOI-1612.01   0.820000    4.420000   29.820000
# KOI-283.02    0.840000   77.700000   55.000000
# KOI-321.02    0.850000   24.390000   16.130000
# KOI-82.03     0.880000    4.920000   24.500000
# KOI-116.04    0.950000  -41.000000   39.750000
# Kepler-68 c   0.952149   28.000000   18.000000
# KOI-246.02    1.000000   10.770000   17.290000
# KOI-1442.01   1.070000    0.290000    5.700000
# KOI-82.02     1.180000   13.270000    6.460000
# KOI-1925.01   1.190000    8.880000   20.600000
# Kepler-78 b   1.200000    5.300000    1.800000
# KOI-41.02     1.320000   14.250000    6.330000
# KOI-321.01    1.430000   11.820000    2.700000
# Kepler-10 b   1.460000    8.150000    2.260000
# KOI-305.01    1.480000   10.900000    2.820000
# KOI-292.01    1.480000    5.440000    3.480000
# Kepler-36 b   1.484674    7.460000    0.665000
# KOI-69.01     1.500000    4.170000    3.290000
# CoRoT-7 b     1.580000   10.388944    2.600240
# KOI-41.03     1.610000   -5.720000    6.000000
# KOI-94 b      1.710000   10.100000    5.500000
# Kepler-11 b   1.800000    1.720000    1.080000
# KOI-153.02    1.820000    6.600000    3.000000
# KOI-148.01    1.880000    3.230000    1.840000
# Kepler-20 b   1.908295    6.500000    2.350000
# KOI-245.01    1.940000    1.300000    3.670000
# 55 Cnc e      1.990000    5.872439    0.792862
# KOI-299.01    1.990000    2.180000    1.210000
# Kepler-18 b   2.000018    4.900000    2.400000
# KOI-148.03    2.040000    5.080000    3.120000
# KOI-153.01    2.190000   -2.440000    2.700000
# KOI-41.01     2.200000    0.350000    1.650000
# KOI-82.01     2.220000    4.680000    1.120000
# Kepler-68 b   2.307940    3.320000    0.920000
# KOI-246.01    2.330000    2.600000    0.740000
# HD 97658 b    2.339998    3.440000    0.865000
# KOI-123.01    2.370000    0.300000    2.200000
# KOI-283.01    2.410000    6.000000    1.980000
# Kepler-11 f   2.490000    0.690000    0.300000
# KOI-116.01    2.500000    3.280000    1.560000
# KOI-123.02    2.520000    0.650000    2.300000
# KOI-116.02    2.560000    3.100000    2.070000
# GJ 1214 b     2.650000    1.914083    0.333105
# KOI-261.01    2.670000    2.260000    1.110000
# KOI-244.02    2.710000    2.500000    1.100000
# KOI-148.02    2.710000    4.010000    0.910000
# Kepler-20 d   2.747545    2.035000    2.035000
# Kepler-11 c   2.870000    0.660000    0.500000
# Kepler-20 c   3.067259    2.910000    0.965000
# Kepler-11 d   3.120000    1.280000    0.210000
# KOI-108.01    3.370000    2.020000    0.590000
# KOI-122.01    3.420000    1.710000    0.370000
# KOI-104.01    3.510000    1.450000    0.260000
# Kepler-36 c   3.675716    0.890000    0.060000
# Kepler-30 b   3.896522    1.020000    0.130000

# %%
#%matplotlib osx
fig = plt.figure(figsize=(8,8));
ax = fig.add_subplot(111,xscale='log');
rho_resid = sp.rho - rho_pred
#notnan = numpy.logical_not(numpy.isnan(sp.flux))
ax.errorbar(sp_clean.flux, sp_clean.rho, 
            xerr=sp_clean.uflux, yerr=sp_clean.urho, 
            fmt='o', alpha = 0.5, capsize=0);
ax.set_xlabel('Flux (Earth flux)', fontsize=18);
ax.set_ylabel('Planet Density (g/cc)', fontsize=18);
pyplot.axis([0,4000,-5,15])
fig.show();
pearsonr(sp_clean.flux, sp_clean.rho)
# Out:
# (0.20843924283797419, 0.15972241159461736)

# %%
#plot residuals
fig = plt.figure(figsize=(14,14));
xarr = [sp.per, sp.a, sp.flux, sp.mstar, sp.rstar, sp.logg, sp.fe, sp.age, sp.vsini]
xarr_err = [None, sp.ua, sp.uflux, sp.umstar, sp.urstar, 
            None, sp.ufe, None, None]
xtit = ['Period (d)','a (AU)','Flux (Earth)',
        '$M_\star$ ($\mathrm{M_{Sun}}$)','$R_\star$ ($\mathrm{R_{Sun}}$)','log(g)',
        '[Fe/H]','Age (Gyr)','Vsini (km/s)']
xscale = ['log','log','log','linear','linear','linear','linear','linear','log']
fig, axarr = plt.subplots(3, 3, sharey=True);
ys = sp.m_resid
yerr = sp.um
yttv = yarr[sp.ttv==1]
yerrttv = yarr_err[sp.ttv==1]
for i in xrange(0,3):
    for j in xrange(0,3):
        xs = xarr[3*i + j]
        xttv = xs[sp.ttv==1]
        xerr = xarr_err[3*i + j]
#        notnan = np.logical_not(np.isnan(xs))
#        xs = xs[notnan]
#        ys = yarr[notnan]
#        yerr = yarr_err[notnan]
#        if xerr is not None: xerr = xerr[notnan]
        axarr[i,j].errorbar(xs,ys, xerr=xerr, yerr=yerr, alpha = 0.5, marker='o', fmt='o')
#        if len(xttv) > 0:
#            if xerr is not None: xerrttv = xerr[sp.ttv==1] 
#            else: xerrttv=None
#            notnanttv = np.logical_not(np.isnan(xttv))
#            xttv = xttv[notnanttv]
#            yttv = yttv[notnanttv]
#            yerrttv = yerrttv[notnanttv]
#            if xerr is not None: xerrttv = xerrttv[notnanttv]
#            print xtit[3*i+j]
#            print len(xttv), len(yttv), len(yerrttv)
        axarr[i,j].errorbar(xttv,yttv,xerr=xerrttv,yerr=yerrttv, 
                            alpha = 0.5, marker='o', fmt='o', c='orange')
        if xscale[3*i + j]=='log': axarr[i,j].set_xscale('log')
        if j==0: axarr[i,j].set_ylabel('Residual Mass ($\mathrm{M_E}$)', fontsize=16)
        axarr[i,j].set_xlabel(xtit[3*i+j], fontsize=16)
fig.set_size_inches(12,12);
subplots_adjust(wspace=0.1)
subplots_adjust(hspace=0.5)
#fig.ylabel('Residual Mass')
fig.show();
plt.savefig('mr_resids.png',dpi=100)
plt.savefig('mr_resids.eps', format='eps', dpi=300)

# %%
notnan = np.logical_not(np.isnan(sp.fe))
fe_r = pearsonr(sp[notnan].fe,m_resid[notnan])
print "Prob. Fe and resid correlation is real:",(1.-fe_r[1])**9.
# Out:
# Prob. Fe and resid correlation is real: 0.486072205977

# %%
r = []
for x in xarr:
    print x
    notnan = np.logical_not(np.isnan(x))
    rx = pearsonr(x[notnan], m_resid(notnan))
    print rx
    r.append(rx)
pearsonr(sp[notnan].fe, rho_resid[notnan])
out = leastsq(errfunc,  [0.,10], 
              args=(sp[notnan].fe, sp[notnan].rho, sp[notnan].urho),full_output=1)
out[0]   
#[r.append(pearsonr(x[np.logical_not(np.isnan(x))],m_resid[np.logical_not(np.isnan(x)) for x in xarr]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-c3d4dde6bf9c> in <module>()
#       3     print x
#       4     notnan = np.logical_not(np.isnan(x))
# ----> 5     rx = pearsonr(x[notnan], m_resid(notnan))
#       6     print rx
#       7     r.append(rx)
#
# TypeError: 'Series' object is not callable
# name
# 55 Cnc e         0.736546
# CoRoT-7 b        0.853585
# GJ 1214 b        1.580405
# HD 97658 b       9.490900
# KOI-104.01       2.508060
# KOI-108.01      15.965400
# KOI-116.01      13.570800
# KOI-116.02      43.844500
# KOI-116.03       6.164860
# KOI-116.04      23.980200
# KOI-122.01      11.523100
# KOI-123.01       6.481630
# KOI-123.02      21.222700
# KOI-1442.01      0.669310
# KOI-148.01       4.778000
# KOI-148.02       9.673950
# KOI-148.03      42.896100
# KOI-153.01       8.925070
# KOI-153.02       4.754000
# KOI-1612.01      2.465020
# KOI-1925.01     68.958400
# KOI-244.02       6.238500
# KOI-245.01      39.792200
# KOI-245.02      21.302000
# KOI-245.03      13.367500
# KOI-246.01       5.398750
# KOI-246.02       9.605040
# KOI-261.01      16.238500
# KOI-283.01      16.092000
# KOI-283.02      25.516900
# KOI-292.01       2.586640
# KOI-299.01       1.541680
# KOI-305.01       4.603580
# KOI-321.01       2.426290
# KOI-321.02       4.623320
# KOI-41.01       12.815900
# KOI-41.02        6.887050
# KOI-41.03       35.333100
# KOI-69.01        4.726740
# KOI-82.01       16.145700
# KOI-82.02       10.311700
# KOI-82.03       27.453600
# KOI-82.04        7.071420
# KOI-82.05        5.286960
# KOI-94 b         3.743208
# Kepler-10 b      0.837495
# Kepler-11 b     10.303900
# Kepler-11 c     13.024100
# Kepler-11 d     22.684500
# Kepler-11 f     46.688800
# Kepler-18 b      3.504725
# Kepler-20 b      3.696122
# Kepler-20 c     10.854092
# Kepler-20 d     77.611840
# Kepler-30 b     29.334000
# Kepler-36 b     13.839890
# Kepler-36 c     16.238550
# Kepler-68 b      5.398763
# Kepler-68 c      9.605085
# Kepler-78 b      0.354167
# Name: per, Length: 60, dtype: float64
# ERROR: TypeError: 'Series' object is not callable [IPython.core.interactiveshell]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-94-50590700a3fe> in <module>()
# ----> 1 m_resid.ix['Kepler-11 b',:]
#
# /Users/lweiss/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#      45                 pass
#      46
# ---> 47             return self._getitem_tuple(key)
#      48         else:
#      49             return self._getitem_axis(key, axis=0)
#
# /Users/lweiss/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     266         for i, key in enumerate(tup):
#     267             if i >= self.obj.ndim:
# --> 268                 raise IndexingError('Too many indexers')
#     269
#     270             if _is_null_slice(key):
#
# IndexingError: Too many indexers
# ERROR: IndexingError: Too many indexers [pandas.core.indexing]

# %%
# test polynomial fitting
# %matplotlib osx
my_poly = lambda x: 14 - 8 * x + 2 * x**2.
x = arange(0,4.1,0.1)
y = my_poly(x)
noise = np.random.normal(0,3,len(y))
noisy_data = y + noise
out5 = np.polynomial.polynomial.polyfit(x,noisy_data, 2, rcond=None, full=True)
my_pars = out5[0]
fig = plt.figure();
ax = fig.add_subplot(111);
ax.errorbar(x, noisy_data, yerr=[1.]*len(x), fmt='o', markersize=5, 
             alpha =0.5, color='k', capsize=0, elinewidth=2); # black option
ax.plot(x,y,label=("y = %.1f + %.1f x + %.1f x^2" % (my_pars[0], my_pars[1], my_pars[2])))
for r in xrange(0,4):
    mask = (r < x) & (x < r+1)
    xbin,ybin,yerr = x[mask],noisy_data[mask],noise[mask]
    ax.scatter((np.average(xbin, weights = (1./yerr**2.))),(np.average(ybin, weights = 1./yerr**2.)), s=100)
ax.legend();
plt.show();

# %%
len(df)
# Out:
# 247

# %%
notnan = numpy.logical_not(numpy.isnan(sp.fe))
from scipy.stats.stats import pearsonr
pearsonr(sp[notnan].fe, m_resid[notnan])
# Out:
# (0.22198951197735173, 0.10010645022745331)

# %%
from scipy.stats import linregress

# %%
linregress(sp.r, sp.m)
# Out:
# (3.4158692504561037,
#  -1.1279750447066093,
#  0.60858818672539539,
#  2.4874627614620931e-07,
#  0.58479429340422384)

# %%
print ssxx/n
# Out:
# 0.729295773867

# %%
print np.mean(sp.ur**2.)
# Out:
# 0.0186294088591

# %%
from scipy import stats

# %%
import scikits.statsmodels.api as sm

# %%
sm.add_constant(sp.r)
model = sm.WLS(sp.m,sp.r,1./sp.um**2.)
result = model.fit()
# Out:
# WARNING: FutureWarning: The default of `prepend` will be changed to True in the next release, use explicit prepend [scikits.statsmodels.tools.tools]

# %%
result.params
# Out:
# array([ 2.72064592])

# %%
print const
# Out:
# <module 'astropy.constants' from '/Users/lweiss/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/astropy/constants/__init__.py'>

# %%
const.M_earth.to('g')
# Out:
# <Quantity 5.9742e+27 g>

# %%
max(sp.flux)
# Out:
# 3572.0477640885611

# %%
fig = plt.figure();
ax = fig.add_subplot(111);
df['flux'].hist(ax=ax)
medf
# Out:
# 911.29362233699521

# %%
sp.ix[['55 Cnc e', 'CoRoT-7 b','GJ 1214 b'],['fe','ufe']]
# Out:
#                  fe   ufe
# 55 Cnc e   0.314513  0.03
# CoRoT-7 b  0.050000  0.04
# GJ 1214 b       NaN   NaN

# %%
from scipy.stats import t as studentt
from scipy.stats import ttest_ind

# %%
ttest_ind?

# %%
ttest_ind(sp.m_resid.loc[sp.ttv==0].loc[sp.r > 1.5], sp.m_resid.loc[sp.ttv==1].loc[sp.r > 1.5])
# Out:
# (array(1.7187440139713788), 0.094495879640871971)
